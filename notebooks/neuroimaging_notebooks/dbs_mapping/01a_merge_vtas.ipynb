# %% [markdown]
# Merge Files within a CSV

# %%
from calvin_utils.nifti_utils.merge_vta_columns import MergeVTAColumns

runner = MergeVTAColumns(
    csv_path='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/spreadsheets/master_list.csv',
    vta_cols=["stimpyper_optimized_left_vtas", "stimpyper_optimized_right_vtas"],
    subject_col="subject",
    output_col="stimpyper_optimized_bilateral_vtas",
    output_dir='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/merged_vtas/stimpyper_optimized_vtas'
)
df, mask_path = runner.run()

# %% [markdown]
# Find Files to Merge Directly

# %%
from calvin_utils.nifti_utils.subject_mask_resample import SubjectMaskResampler
runner = SubjectMaskResampler(
    glob_pattern="/Volumes/HowExp/datasets/03h_ADVANCE_Alzheimer_DBS/subjects/sub-*/stimulations/MNI_ICBM_2009b_NLIN_ASYM/gs_20180403170745/vat_efield_*.nii",
    output_dir="/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/merged_vtas",
    subject_extractor=r"sub-(\d+)"
)

outputs = runner.run()
