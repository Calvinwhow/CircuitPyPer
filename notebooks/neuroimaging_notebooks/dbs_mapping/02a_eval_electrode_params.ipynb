# %% [markdown]
# Run Unpaired analysis

# %%
from calvin_utils.neuroimaging_utils.dbs_utils.eval_stim_params import EvalStimParams

runner = EvalStimParams(
    csv_path='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/spreadsheets/master_list.csv',
    json_col="stimpyper_optimized_stimparams_average",
    subject_col="subject",  # optional
    contact_plot_title="Contact amplitudes",
    out_dir='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/stim_params/opt-vs-clinician/t'
)

contact_df, sum_df = runner.run()

# %% [markdown]
# Run Paired Analysis

# %%
from calvin_utils.neuroimaging_utils.dbs_utils.eval_stim_params import EvalStimParamsPair

runner = EvalStimParamsPair(
    csv_path='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/spreadsheets/master_list.csv',
    json_col_a="stimpyper_optimized_stimparams_average",
    json_col_b="stimpyper_clinician_stimparams_average_indexed",
    subject_col="subject",  # optional
    contact_plot_title="Contact amplitudes",
    out_dir=None,
    plot_type="box",  # or "dynamite", "cdf", "pair_superiority"
    group_labels=["Optimized", "Clinician"],  # optional
)

contact_df, sum_df = runner.run()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 14
#       1 from calvin_utils.neuroimaging_utils.dbs_utils.eval_stim_params import EvalStimParamsPair
#       3 runner = EvalStimParamsPair(
#       4     csv_path='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/spreadsheets/master_list.csv',
#       5     json_col_a="stimpyper_optimized_stimparams_average",
#    (...)
#      11     group_labels=["Optimized", "Clinician"],  # optional
#      12 )
# ---> 14 contact_df, sum_df = runner.run()
#
# File ~/Software_Local/calvin_utils_project/circuit_pyper/calvin_utils/neuroimaging_utils/dbs_utils/eval_stim_params.py:442, in EvalStimParamsPair.run(self)
#     440 self._load_csv()
#     441 self._validate_columns_pair()
# --> 442 arrays_a, arrays_b = self._load_json_arrays_pair()
#     443 self._arrays = arrays_a + arrays_b
#     444 self._validate_lengths(self._arrays)
#
# File ~/Software_Local/calvin_utils_project/circuit_pyper/calvin_utils/neuroimaging_utils/dbs_utils/eval_stim_params.py:469, in EvalStimParamsPair._load_json_arrays_pair(self)
#     467         print("Paired input required: missing JSON path in one of the pair columns. Dropping row.")
#     468         continue
# --> 469     arrays_a.append(self._read_json_list(p_a))
#     470     arrays_b.append(self._read_json_list(p_b))
#     471 if not arrays_a or not arrays_b:
#
# File ~/Software_Local/calvin_utils_project/circuit_pyper/calvin_utils/neuroimaging_utils/dbs_utils/eval_stim_params.py:150, in EvalStimParams._read_json_list(self, path)
#     148 def _read_json_list(self, path: str) -> List[float]:
#     149     path = os.path.expanduser(path)
# --> 150     with open(path, "r") as f:
#     151         data = json.load(f)
#     152     if not isinstance(data, list):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/HowExp/datasets/03h_ADVANCE_Alzheimer_DBS/subjects/sub-123/stimulations/optimized/stimpyper/electrode_left_1/stimparams_elec_1_average.json'
