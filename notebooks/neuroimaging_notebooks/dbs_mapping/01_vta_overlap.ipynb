# %% [markdown]
# # Correlate Overlap of VTAs with Another set of VTAs to Outcomes

# %%
from calvin_utils.neuroimaging_utils.nifti_utils.dice_vta import DiceVTA


runner = DiceVTA(
    csv_path='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/spreadsheets/master_list_under65.csv',
    vta_col1="stimpyper_optimized_bilateral_vtas",
    vta_col2="stimpyper_clinician_bilateral_vtas",
    dep_var_col="Month_12_Delta_ADASMem",
    subject_col="subject",
    output_dir='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/similarity_to_optimal/under65/bilateral',
    mask_path=None,
    scatter_title="Memory Outcomes by Optimality",
    scatter_x_label="Similarity to Optimal (Dice)",
    scatter_y_label="1-Year Memory Change (ADAS-Mem)",
    )

overlap_df = runner.run()
