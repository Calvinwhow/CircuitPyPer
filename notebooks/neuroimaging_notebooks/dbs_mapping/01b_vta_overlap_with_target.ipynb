# %%
from calvin_utils.neuroimaging_utils.nifti_utils.dice_vta import DiceVTATargetOverlap

plotter = DiceVTATargetOverlap(
    csv_path="/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/spreadsheets/master_list_over65.csv",
    vta_col1="stimpyper_optimized_bilateral_vtas",
    vta_col2="stimpyper_clinician_bilateral_vtas",
    target_path="/Users/cu135/hires_backdrops/convergent_memory_target_map.nii.gz",
    dep_var_col="Month_12_Delta_ADASMemImprovement",
    subject_col="subject",
    output_dir=None,
    mask_path=None,              # optional
    threshold=0.0,
    empty_value=1.0,
    plot_type="box",             # "box" | "dynamite" | "pair_superiority"
    group_labels=["VTA1", "VTA2"],
    comparison_title="VTA overlap with target",
    scatter_title_a=None,
    scatter_title_b=None,
    scatter_x_label="Dice overlap",
    scatter_y_label="Outcome",
)
df = plotter.run()
