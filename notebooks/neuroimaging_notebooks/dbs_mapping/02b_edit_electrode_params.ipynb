# %% [markdown]
# Average Two Stim Parameter Files

# %%
from calvin_utils.statistical_utils.modify_stim_params import ModifyStimParams
mod = ModifyStimParams('/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/spreadsheets/master_list.csv')
mod.average_pairs("stimpyper_optimized_left_stimparams", "stimpyper_optimized_right_stimparams")

# %% [markdown]
# Reindex a Stim Parameters to Specific Contacts

# %%
from calvin_utils.statistical_utils.modify_stim_params import ModifyStimParams
mod = ModifyStimParams("/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/spreadsheets/master_list.csv")
mod.index_series("stimpyper_clinician_right_stimparams_average", indices=[0,1,2,3])
