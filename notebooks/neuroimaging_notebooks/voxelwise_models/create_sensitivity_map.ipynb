# %% [markdown]
# # 00 - Import CSV with All Data
# **The CSV is expected to be in this format**
# - ID and absolute paths to niftis are critical
# ```
# +-----+----------------------------+--------------+--------------+--------------+
# | ID  | Nifti_File_Path            | Covariate_1  | Covariate_2  | Covariate_3  |
# +-----+----------------------------+--------------+--------------+--------------+
# | 1   | /path/to/file1.nii.gz      | 0.5          | 1.2          | 3.4          |
# | 2   | /path/to/file2.nii.gz      | 0.7          | 1.4          | 3.1          |
# | 3   | /path/to/file3.nii.gz      | 0.6          | 1.5          | 3.5          |
# | 4   | /path/to/file4.nii.gz      | 0.9          | 1.1          | 3.2          |
# | ... | ...                        | ...          | ...          | ...          |
# +-----+----------------------------+--------------+--------------+--------------+
# ```

# %% [markdown]
# Prep Output Direction

# %%
# Specify where you want to save your results to
out_dir = '/Users/cu135/Library/CloudStorage/OneDrive-Personal/OneDrive_Documents/Research/2023/subiculum_cognition_and_age/figures/Figures/3_cohort_anova_ancova/split_by_stim'

# %% [markdown]
# Information on Master List CSV

# %%
# Specify the path to your CSV file containing NIFTI paths
input_csv_path = '/Users/cu135/Dropbox (Partners HealthCare)/studies/cognition_2023/metadata/master_list_proper_subjects.csv'
sheet = None

# %%
from calvin_utils.permutation_analysis_utils.statsmodels_palm import CalvinStatsmodelsPalm
# Instantiate the PalmPrepararation class
cal_palm = CalvinStatsmodelsPalm(input_csv_path=input_csv_path, output_dir=out_dir, sheet=sheet)
# Call the process_nifti_paths method
data_df = cal_palm.read_and_display_data()

# %% [markdown]
# # 02 - Mask Dataframe

# %%
from calvin_utils.nifti_utils.matrix_utilities import apply_mask_to_dataframe
data_df = apply_mask_to_dataframe(data_df, mask_path=None)
data_df

# %% [markdown]
# # 03 - Generate Sensitivity Map

# %%
threshold = 0.452

# %%
from calvin_utils.nifti_utils.sensitivity_analysis import SensitivityTestMap

processor = SensitivityTestMap(data_df, 
                               mask_path=None, 
                               absval=True,
                               sensitivity_threshold=threshold, 
                               output_dir=out_dir,
                               output_name=f'sensitivity_map_t_{int(round(threshold*100))}.nii')
# Run the entire workflow with specified parameters
unmasked_df, html_viewer, _= processor.run()
html_viewer

# %%
[print('\n', hit) for hit in _]
