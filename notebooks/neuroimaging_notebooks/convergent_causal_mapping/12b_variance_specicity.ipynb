# %%
col="Ataxia Rho"
output_dir='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/raynor_network_mapping/results/map_performance_tracking/performance_in_sca'

# %%
import os 
from calvin_utils.neuroimaging_utils.ccm_utils.variance_specificity import VarianceSpecificity

vs = VarianceSpecificity(
    csv_path='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/raynor_network_mapping/results/map_performance_tracking/performance_in_sca/map_performance_tracker.csv',
    col_of_interest=col,
    output_path=os.path.join(output_dir, f'{col}_variance_specificity.svg')
)
rank_df, svg_path, fig, ax = vs.run()
