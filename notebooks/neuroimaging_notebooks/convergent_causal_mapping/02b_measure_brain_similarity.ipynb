# %%
out_dir = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/ccm_memory/results/supplements/vlsm_convergence'

# %% [markdown]
# Enter the path to the dictionary generated by Notebook 01

# %%
dict_path = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/ccm_memory/results/notebook_01/rois/tmp/dataset_dict_pruned.json'

# %% [markdown]
# # 01 - Begin Analysis

# %% [markdown]
# What correlation method would you like to use?
# - Pearson is very fast, but depends on linearity and is sensitive to outliers
# - Spearman is slower, but much more robust

# %% [markdown]
# One or Two-Tail P Values?
#
# - ``` tails = 'one_tail' or tails = 'two_tail' ```
#
# Numer of permutations?
# - Pearson is ~10x faster than Spearman
#
# Would you like to compare maps wiht spearman or pearson?
#
# - ``` method = 'spearman' or method = 'pearson' ```
#
# Would you like to FWE correct the pairwise matrix?
#
# - ``` fwe = True or fwe = False ```

# %%
tails = 'one_tail'
n_permutations = 100
method = 'pearson'
fwe = False
datasets_to_flip = []#'Alzheimer Disease', 'Multiple Sclerosis', 'Penetrating TBI']# ['Parietal TMS Hebscher'] #['adni_Alzheimer', 'corbetta_memory', 'manitoba_memory', 'ms_memory']

# %% [markdown]
# Run it

# %%
from calvin_utils.neuroimaging_utils.ccm_utils.ccm_correlation_analysis import CorrelationAnalysis
correlation_analysis = CorrelationAnalysis(data_dict_path=dict_path, 
                                           method=method, 
                                           datasets_to_flip=datasets_to_flip,
                                           n_permutations=n_permutations,
                                           out_dir=out_dir,
                                           topology_command=None)
p_value, pairwise_p_values = correlation_analysis.run(tails, fwe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 8
#       1 from calvin_utils.neuroimaging_utils.ccm_utils.ccm_correlation_analysis import CorrelationAnalysis
#       2 correlation_analysis = CorrelationAnalysis(data_dict_path=dict_path,
#       3                                            method=method,
#       4                                            datasets_to_flip=datasets_to_flip,
#       5                                            n_permutations=n_permutations,
#       6                                            out_dir=out_dir,
#       7                                            topology_command=None)
# ----> 8 p_value, pairwise_p_values = correlation_analysis.run(tails, fwe)
#
# File ~/Software_Local/calvin_utils_project/circuit_pyper/calvin_utils/neuroimaging_utils/ccm_utils/ccm_correlation_analysis.py:224, in CorrelationAnalysis.run(self, tails, fwe, verbose)
#     223 def run(self, tails='two_tail', fwe=False, verbose=False):
# --> 224     self.perform_permutation_testing()
#     225     self.save_results()
#     227     if tails == 'two_tail':
#
# File ~/Software_Local/calvin_utils_project/circuit_pyper/calvin_utils/neuroimaging_utils/ccm_utils/ccm_correlation_analysis.py:211, in CorrelationAnalysis.perform_permutation_testing(self, datasets_list)
#     208 if datasets_list == []:
#     209     datasets_list = self.data_loader.dataset_paths_dict.keys()
# --> 211 self.corr_map_dict = self._prepare_map_dict(permute=False, datasets_list=datasets_list)
#     212 self.original_similarity_matrix = self.calculate_similarity_matrix(self.corr_map_dict)
#     214 n = len(self.corr_map_dict)
#
# File ~/Software_Local/calvin_utils_project/circuit_pyper/calvin_utils/neuroimaging_utils/ccm_utils/ccm_correlation_analysis.py:79, in CorrelationAnalysis._prepare_map_dict(self, permute, datasets_list)
#      76     data = self.data_loader.load_dataset(dataset_name)
#      78 if permute: np.random.shuffle(data['indep_var'])  # permute the independent variable
# ---> 79 self.correlation_calculator._process_data(data)         # Condense all patient data into a single map
#      80 if dataset_name in self.datasets_to_flip:  self.correlation_calculator.correlation_map *= -1
#      81 map_dict[dataset_name] = self.correlation_calculator.correlation_map
#
# File ~/Software_Local/calvin_utils_project/circuit_pyper/calvin_utils/neuroimaging_utils/ccm_utils/stat_utils.py:172, in CorrelationCalculator._process_data(self, data)
#     170 data['indep_var'] = self._check_for_nans(data['indep_var'])
#     171 if self.method == 'pearson':
# --> 172     self.correlation_map = self._calculate_pearson_r_map(data['niftis'], data['indep_var'])
#     173 elif self.method == 'spearman':
#     174     self.correlation_map = self._calculate_spearman_r_map(data['niftis'], data['indep_var'])
#
# File ~/Software_Local/calvin_utils_project/circuit_pyper/calvin_utils/neuroimaging_utils/ccm_utils/stat_utils.py:147, in CorrelationCalculator._calculate_pearson_r_map(self, niftis, indep_var)
#     145 X_C = X - X_BAR
#     146 Y_C = Y - Y_BAR
# --> 147 NUMERATOR = np.dot(X_C.T, Y_C)
#     148 SST_X = np.sum((X - X_BAR)**2, axis=0)
#     149 SST_Y = np.sum((Y - Y_BAR)**2, axis=0)
#
# ValueError: shapes (1,102) and (37,228483) not aligned: 102 (dim 1) != 37 (dim 0)

# %% [markdown]
# # 02 - Visualize Results

# %% [markdown]
# Similarity matrix (Signs Included)

# %%
limit = correlation_analysis.matrix_heatmap(correlation_analysis.original_similarity_matrix, type='misc', output_path=out_dir, colorscale='viridis')

# %%
correlation_analysis.original_similarity_matrix

# %% [markdown]
# View the Overall Similarities of the Topology, Signs Aside

# %%
import numpy as np
limit = correlation_analysis.matrix_heatmap(np.abs(correlation_analysis.original_similarity_matrix), type='misc', output_path=out_dir+'/heatmap_similarity_absval.svg', colorscale='viridis')

# %% [markdown]
# Permuted Similarity

# %%
import numpy as np
avg_sim_mx = np.mean(np.abs(correlation_analysis.permuted_similarity_tensor), axis=0)
l = correlation_analysis.matrix_heatmap(avg_sim_mx, type='misc', output_path=out_dir+'/heatmap_similarity_permuted.svg', limit=limit, colorscale='viridis')

# %% [markdown]
# Pairwise P values Matrix

# %%
out_dir

# %%
correlation_analysis.matrix_heatmap(pairwise_p_values, type='pvals', output_path=out_dir)

# %%
pairwise_p_values

# %% [markdown]
# # 03 - Run Specific Comparisons

# %% [markdown]
# You will have to generate and pass a contrast matrix to see if the comparison of interest exceeds the null distribution

# %%
correlation_analysis.example_identity_contrast(correlation_analysis.original_similarity_matrix)

# %%
contrast_matrix = []

# %% [markdown]
# Run the comparisons of interest

# %%
stat, p = correlation_analysis.contrast_outer_summation(correlation_analysis.original_similarity_matrix, correlation_analysis.permuted_similarity_tensor, contrast_matrix)
