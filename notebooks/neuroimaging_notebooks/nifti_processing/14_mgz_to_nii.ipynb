# %% [markdown]
# Convert a .mgz file to a .nii.gz file

# %%
file_structure = '/Users/cu135/hires_backdrops/46051074/mri/orig/001.mgz'

# %%
from calvin_utils.file_utils.mgz_to_nii import mgz_to_nii
mgz_to_nii(file_structure)
# Out:
# Converted: /Users/cu135/hires_backdrops/46051074/mri/orig/001.mgz -> /Users/cu135/hires_backdrops/46051074/mri/orig/001.nii.gz
