# %%
path = '/Volumes/HowExp/datasets/03h_ADVANCE_Alzheimer_DBS/subjects/sub-*/stimulations/MNI_ICBM_2009b_NLIN_ASYM/gs_20180403170745/stimpyper/electrode_left/clinician_resampled.nii.gz'
out_dir = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/vta'

# %%
from calvin_utils.neuroimaging_utils.ccm_utils.bounding_box import NiftiBoundingBox
from glob import glob
bbox = NiftiBoundingBox(glob(path))
bbox.gen_mask(out_dir)

# %% [markdown]
# Enter Specific Files

# %%
out_path='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/vta_masks'
files = [
    '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/vta_masks/simbio_clinical-vta_mask.nii.gz',
    '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/vta_masks/stimpyper_clinical_mask.nii.gz',
    '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/vta_masks/stimpyper_optimized_mask.nii.gz'
]

# %%
from calvin_utils.neuroimaging_utils.ccm_utils.bounding_box import NiftiBoundingBox
bbox = NiftiBoundingBox(files)
bbox.gen_mask(out_path)
