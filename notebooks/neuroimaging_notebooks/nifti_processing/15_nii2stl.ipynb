# %%
from calvin_utils.neuroimaging_utils.nifti_utils.nii2stl import nifti_mask_to_stl
nifti_mask_to_stl("/Users/cu135/hires_backdrops/t/MesialTemporalMask_1mm_clean.nii.gz", "/Users/cu135/hires_backdrops/t/MesialTemporalMask_dilated.stl", step_size=1, smooth_iters=5)
