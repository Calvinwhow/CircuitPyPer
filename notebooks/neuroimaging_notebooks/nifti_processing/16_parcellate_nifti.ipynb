# %% [markdown]
# Takes a voxelwise nifti and parcellates it

# %%
from calvin_utils.permutation_analysis_utils import ParcelwiseDamageMap

viewer = ParcelwiseDamageMap(
    target_map="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/symptom_on_lhs/proper_regressions/TotalBarsScore-on-Nifti_File_Path/regression/contrast_tval_0.nii.gz",
    parcel_path="/Volumes/HowExp/resources/atlases/mni_space/aal_atlas/AAL_MNI_V7_fine_rois/*.nii.gz",
    mask_path="/Users/cu135/Software_Local/calvin_utils_project/circuit_pyper/resources/MNI152_T1_2mm_brain_mask.nii",
    out_dir="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/symptom_on_lhs/proper_regressions/TotalBarsScore-on-Nifti_File_Path/parcellated_files",
    output_name="TotalBars-wholebrain",
    selected_damage="avg_in_target",
).run()
# Out:
# Attempting to import from globbable path. Expecting globbable filenames.
# Attempting to import from: /Volumes/HowExp/resources/atlases/mni_space/aal_atlas/AAL_MNI_V7_fine_rois/*.nii.gz
# 88it [00:00, 494.12it/s]
# Saving files: 100%|██████████| 1/1 [00:00<00:00, 77.97it/s]
