# %%
from calvin_utils.neuroimaging_utils.nifti_utils.damage_score_utils import DamageScorer

scorer = DamageScorer(mask_path='/Users/cu135/Software_Local/calvin_utils_project/circuit_pyper/resources/MNI152_T1_2mm_brain_mask.nii')
# df = scorer.score_csv_against_target(
#     csv_path="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/master_list_redo.csv",
#     path_col="onetouch_path",
#     target_path="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/batch_cv_loocv/AffectTotal/contrast_tval_0.nii.gz",
#     selected_damage=["cosine"],
#     target_suffix="Affect_Total",
# )

# df = scorer.score_csv_against_target(
#     csv_path="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/master_list_redo.csv",
#     path_col="onetouch_path",
#     target_path="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/batch_cv_loocv/TotalCCASFailScore/contrast_tval_0.nii.gz",
#     selected_damage=["cosine"],
#     target_suffix="Total_CCAS_Fail",
# )

df = scorer.score_csv_against_target(
    csv_path="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/master_list_redo.csv",
    path_col="onetouch_path",
    target_path="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/attempted_localization/total-bars/regression_0/contrast_tval_0.nii.gz",
    selected_damage=["cosine"],
    target_suffix="Total_BARS_redo",
)
