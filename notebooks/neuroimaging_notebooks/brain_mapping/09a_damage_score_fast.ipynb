# %%
from calvin_utils.neuroimaging_utils.nifti_utils.damage_score_utils import DamageScorer

scorer = DamageScorer(mask_path='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/vta_masks/overall_vta_mask.nii.gz')
df = scorer.score_csv_against_target(
    csv_path="...",
    path_col="stimpyper_clinician_bilateral_vtas",
    target_path="...",
    selected_damage=["avg_in_subject", "avg_in_target", "dice"],
    target_suffix="memnet",
)
