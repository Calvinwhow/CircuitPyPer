# %%
from calvin_utils.neuroimaging_utils.nifti_utils.damage_score_utils import DamageScorer

scorer = DamageScorer(mask_path='/Users/cu135/Software_Local/calvin_utils_project/circuit_pyper/resources/MNI152_T1_2mm_brain_mask.nii')
df = scorer.score_csv_against_target(
    csv_path="/Volumes/HowExp/datasets/01a_ADNI_Alzheimer_Atrophy/metadata/cleaned_information/master.csv",
    path_col="fluid_atrophy_path_smoothed",
    target_path="/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/atrophy_seeds_2023/Figures/supplement_validation_diagnostic/voxelwise/composite/avg_maps/gm/alzheimer/dataset_avg_map.nii.gz",
    selected_damage=["cosine"],
    target_suffix="GM_AD",
)

df = scorer.score_csv_against_target(
    csv_path="/Volumes/HowExp/datasets/01a_ADNI_Alzheimer_Atrophy/metadata/cleaned_information/master.csv",
    path_col="fluid_atrophy_path_smoothed",
    target_path="/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/atrophy_seeds_2023/Figures/supplement_validation_diagnostic/voxelwise/composite/avg_maps/gm/mci/dataset_avg_map.nii.gz",
    selected_damage=["cosine"],
    target_suffix="GM_MCI",
)

df = scorer.score_csv_against_target(
    csv_path="/Volumes/HowExp/datasets/01a_ADNI_Alzheimer_Atrophy/metadata/cleaned_information/master.csv",
    path_col="fluid_atrophy_path_smoothed",
    target_path="/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/atrophy_seeds_2023/Figures/supplement_validation_diagnostic/voxelwise/composite/avg_maps/gm/normal/dataset_avg_map.nii.gz",
    selected_damage=["cosine"],
    target_suffix="GM_CN",
)
# Out:
# Target image: shape=(91, 109, 91), zooms=(2.0, 2.0, 2.0)
# Resample space (mask): shape=(91, 109, 91), zooms=(2.0, 2.0, 2.0)
# [resample] target_path shape=(91, 109, 91), zooms=(2.0, 2.0, 2.0) -> space shape=(91, 109, 91), zooms=(2.0, 2.0, 2.0)
# [no resample] /Volumes/HowExp/datasets/01a_ADNI_Alzheimer_Atrophy/neuroimaging/all_patients/sub-002_S_0295/ses-01/unthresholded_tissue_segment_z_scores/sub-002_S_0295_ses-01_cerebrospinal_fluid_fwhm4.nii.gz -> resample space
# [no resample] /Volumes/HowExp/datasets/01a_ADNI_Alzheimer_Atrophy/neuroimaging/all_patients/sub-002_S_0413/ses-01/unthresholded_tissue_segment_z_scores/sub-002_S_0413_ses-01_cerebrospinal_fluid_fwhm4.nii.gz -> resample space
# [no resample] /Volumes/HowExp/datasets/01a_ADNI_Alzheimer_Atrophy/neuroimaging/all_patients/sub-002_S_0559/ses-01/unthresholded_tissue_segment_z_scores/sub-002_S_0559_ses-01_cerebrospinal_fluid_fwhm4.nii.gz -> resample space
# ...
