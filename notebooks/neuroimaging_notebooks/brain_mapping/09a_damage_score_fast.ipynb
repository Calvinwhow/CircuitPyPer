# %%
from calvin_utils.neuroimaging_utils.nifti_utils.damage_score_utils import DamageScorer

scorer = DamageScorer(mask_path=None)
df = scorer.score_csv_against_target(
    csv_path="/Volumes/HowExp/datasets/03h_ADVANCE_Alzheimer_DBS/metadata/stimpyper_vta_target_overlap.csv",
    path_col="tconn",
    target_path="/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/ccm_memory/memory_map/convergent_memory_map.nii",
    selected_damage="spatial_correl",
    target_suffix="",
    resample_to_target=False,   # if true, slcies subject to target. if false, slices target to subject
)
# Out:
# Target image: shape=(91, 109, 91), zooms=(2.0, 2.0, 2.0)
# Resample space (mask): shape=(91, 109, 91), zooms=(2.0, 2.0, 2.0)
# [resample] target_path shape=(91, 109, 91), zooms=(2.0, 2.0, 2.0) -> space shape=(91, 109, 91), zooms=(2.0, 2.0, 2.0)
# [no resample] /Volumes/HowExp/datasets/03h_ADVANCE_Alzheimer_DBS/connectivity_data/vta_published_t_connectivity/101_vat_seed_compound_fMRI_efield_func_seed_T.nii.gz -> resample space
# [no resample] /Volumes/HowExp/datasets/03h_ADVANCE_Alzheimer_DBS/connectivity_data/vta_published_t_connectivity/106_vat_seed_compound_fMRI_efield_func_seed_T.nii.gz -> resample space
# [no resample] /Volumes/HowExp/datasets/03h_ADVANCE_Alzheimer_DBS/connectivity_data/vta_published_t_connectivity/110_vat_seed_compound_fMRI_efield_func_seed_T.nii.gz -> resample space
# [no resample] /Volumes/HowExp/datasets/03h_ADVANCE_Alzheimer_DBS/connectivity_data/vta_published_t_connectivity/114_vat_seed_compound_fMRI_efield_func_seed_T.nii.gz -> resample space
# ...
