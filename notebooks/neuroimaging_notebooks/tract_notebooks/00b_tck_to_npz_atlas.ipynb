# %% [markdown]
# This converts a fiber set sampled from DSI studio to a .npz fiberset (used in this library)

# %%
from calvin_utils.neuroimaging_utils.tract_utils.fiber_atlas_converter import FiberAtlasConverter

FiberAtlasConverter(
    input_path="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/connectomic/subcortex_mask_2mm.tt.tck",
    out_path="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/connectomic/subcortex_mask_2mm.npz",
).run()
