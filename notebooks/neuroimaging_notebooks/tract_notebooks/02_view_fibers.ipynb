# %%
from calvin_utils.neuroimaging_utils.tract_utils.fiber_result_visualizer import FiberResultVisualizer

viz = FiberResultVisualizer(
    values_path="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/connectomic/um1_fibers.npz",
    out_dir="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/connectomic/um1_fibers",
    sign="both",
    min_abs_value=None,
    top_percent=None,
).run()
