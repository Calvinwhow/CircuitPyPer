# %%
from calvin_utils.neuroimaging_utils.tract_utils.tract_density import TractDensity

result = TractDensity(
    fiber_path="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/symptom_on_lhs/standardized-perm1000-fibfilt/TotalBarsScore/regression_0/contrast_tval_FWE_0.fib.npy",
    reference_nifti_path="/Users/cu135/Software_Local/calvin_utils_project/circuit_pyper/resources/MNI152_T1_2mm_brain_mask.nii",
    out_path="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/symptom_on_lhs/standardized-perm1000-fibfilt/TotalBarsScore/regression_0/contrast_tval_FWE_0_ftr.nii.gz",
    fiberset="both",
    threshold=0.05,
).run()
# Out:
# /Users/cu135/Software_Local/calvin_utils_project/circuit_pyper/calvin_utils/neuroimaging_utils/tract_utils/tract_density.py:333: RuntimeWarning: All-NaN slice encountered
#   values.append(float(np.nanmedian(fiber[:, 3])))
# Rasterizing fibers: 100%|██████████| 790/790 [00:00<00:00, 26283.44fiber/s]
