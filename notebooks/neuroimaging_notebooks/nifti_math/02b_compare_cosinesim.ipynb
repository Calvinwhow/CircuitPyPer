# %%
from calvin_utils.nifti_utils.compare_nifti_cosine import NiftiCosineStats

stats = NiftiCosineStats(
    csv_path="/path/to/paths.csv",
    col_a="nifti_a",
    col_b="nifti_b",
    threshold=None,  # set for binarization, e.g. 0.0
)
stats.run()
