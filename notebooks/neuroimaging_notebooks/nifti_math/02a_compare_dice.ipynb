# %%
from calvin_utils.neuroimaging_utils.nifti_utils.compare_nifti_dice import NiftiDiceStats

stats = NiftiDiceStats(
    csv_path='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/optimizer/metadata/master_vtas.csv',
    subject_col="subject",
    nifti_col_a="paths_clinician",
    nifti_col_b="paths_tremortract",
    reference_col="paths_clinician",  # optional
    one_sample_mu=0.5,
    threshold=0.0,
)
stats.run()

# %%
from calvin_utils.neuroimaging_utils.nifti_utils.compare_nifti_dice import NiftiDiceComparisonStats

stats = NiftiDiceComparisonStats(
    csv_path='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/optimizer/metadata/master_vtas.csv',
    target_pair={"paths_gaittract": "paths_clinician"},
    other_pairs={"paths_bradytract": "paths_clinician",
                 "paths_rigiditytract": "paths_clinician",
                 "paths_tremortract": "paths_clinician",
                 "paths_updrstract": "paths_clinician",
                 "paths_clinician":"paths_clinician"},  # optional
    subject_col="subject",
    one_sided=False,
    threshold=0.0,
)
stats.run()
