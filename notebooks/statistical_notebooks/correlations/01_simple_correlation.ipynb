# %% [markdown]
# # Run Correlation-Based Analyses
#
# ### Authors: Calvin Howard.
#
# #### Last updated: July 6, 2023
#
# Use this to assess if a correlation between a dependent variable and an independent variable is statistically significant using permutation analysis.
#
# Further, follow this up with a contrast analysis which sees which categorical variables have significantly different correlations from each other.
#
# Notes:
# - To best use this notebook, you should be familar with mixed effects models

# %% [markdown]
# # 00 - Import CSV with All Data
# **The CSV is expected to be in this format**
# - ID and absolute paths to niftis are critical
# ```
# +-----+----------------------------+--------------+--------------+--------------+
# | ID  | Nifti_File_Path            | Covariate_1  | Covariate_2  | Covariate_3  |
# +-----+----------------------------+--------------+--------------+--------------+
# | 1   | /path/to/file1.nii.gz      | 0.5          | 1.2          | 3.4          |
# | 2   | /path/to/file2.nii.gz      | 0.7          | 1.4          | 3.1          |
# | 3   | /path/to/file3.nii.gz      | 0.6          | 1.5          | 3.5          |
# | 4   | /path/to/file4.nii.gz      | 0.9          | 1.1          | 3.2          |
# | ... | ...                        | ...          | ...          | ...          |
# +-----+----------------------------+--------------+--------------+--------------+
# ```

# %%
# Specify the path to your CSV file containing NIFTI paths
input_csv_path = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/atrophy_and_stim/data/master_list_v2.csv'
sheet = None #'Sheet1' #'master_list'

# %%
# Specify where you want to save your results to
out_dir = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/atrophy_and_stim/results/fornix_dbs/memory_on_atrophy/scatters'

# %%
from calvin_utils.permutation_analysis_utils.statsmodels_palm import CalvinStatsmodelsPalm
# Instantiate the PalmPrepararation class
cal_palm = CalvinStatsmodelsPalm(input_csv_path=input_csv_path, output_dir=out_dir, sheet=sheet)
# Call the process_nifti_paths method
data_df = cal_palm.read_and_display_data()
data_df
# Out:
#      cohort_key stimulation_modality subject_id  subject  delta_adasmem  \
# 0    fornix_dbs                  DBS    sub-101    101.0            NaN
# 1    fornix_dbs                  DBS    sub-102    102.0            NaN
# 2    fornix_dbs                  DBS    sub-103    103.0            NaN
# 3    fornix_dbs                  DBS    sub-105    105.0            NaN
# 4    fornix_dbs                  DBS    sub-106    106.0            NaN
# ..          ...                  ...        ...      ...            ...
# 113         bnm                  DBS       Pat8      NaN            NaN
# 114         bnm                  DBS       Pat9      NaN            NaN
# 115         bnm                  DBS       Pat4      NaN            NaN
# 116         bnm                  DBS      Pat10      NaN            NaN
# 117         bnm                  DBS      Pat11      NaN            NaN
#
#      percent_improvement_adas   age  baseline_adas  followup_adas  \
# 0                   -0.214286  62.0           28.0           34.0
# 1                   -0.363636  77.0           22.0           30.0
# 2                   -0.789474  76.0           19.0           34.0
# 3                   -0.105263  50.0           19.0           21.0
# 4                   -0.384615  66.0           13.0           18.0
# ..                        ...   ...            ...            ...
# 113                -11.111111   NaN            NaN            NaN
# 114                 17.500000   NaN            NaN            NaN
# 115                  8.330000   NaN            NaN            NaN
# 116                 33.330000   NaN            NaN            NaN
# 117                -25.000000   NaN            NaN            NaN
#
#                                      atrophy_path  ... data__yeo7__Limbic_FC  \
# 0    files/fornix_dbs/sub-101/atrophy_path.nii.gz  ...             14.435060
# 1    files/fornix_dbs/sub-102/atrophy_path.nii.gz  ...             17.193963
# 2    files/fornix_dbs/sub-103/atrophy_path.nii.gz  ...             14.630112
# 3    files/fornix_dbs/sub-105/atrophy_path.nii.gz  ...              8.887128
# 4    files/fornix_dbs/sub-106/atrophy_path.nii.gz  ...             14.001423
# ..                                            ...  ...                   ...
# 113            files/bnm/Pat8/atrophy_path.nii.gz  ...             -0.493502
# 114            files/bnm/Pat9/atrophy_path.nii.gz  ...             -0.676706
# 115            files/bnm/Pat4/atrophy_path.nii.gz  ...             -0.399816
# 116           files/bnm/Pat10/atrophy_path.nii.gz  ...             -1.000484
# 117           files/bnm/Pat11/atrophy_path.nii.gz  ...             -0.002404
#
#     data__yeo7__Frontoparietal_A  data__yeo7__Frontoparietal_FC  \
# 0                       0.295749                      -9.849473
# 1                       0.408067                     -10.334266
# 2                       0.359400                      -9.882224
# 3                       0.216878                      -3.358576
# 4                       0.245907                      -9.856519
# ..                           ...                            ...
# 113                     2.978483                      -2.289092
# 114                     0.356289                      -4.067742
# 115                     2.863390                      -1.143710
# 116                     2.489321                       0.048624
# 117                     2.437744                      -0.271703
#
#      data__yeo7__Default_A  data__yeo7__Default_FC  Month_12_Delta_ADASMem  \
# 0                 0.485158                2.376464                     NaN
# 1                 0.354756                3.755009                    -6.0
# 2                 0.475581                4.449948                    -4.0
# 3                 0.181887                0.902216                     NaN
# 4                 0.280630                4.013440                    -6.0
# ..                     ...                     ...                     ...
# 113               4.717349               -3.710564                     NaN
# 114               0.315375               -3.146983                     NaN
# 115               3.405063               -4.107881                     NaN
# 116               2.914052               -4.181682                     NaN
# 117               2.994719               -3.648365                     NaN
#
#                     stimpyper_optimized_bilateral_vtas  \
# 0                                                  NaN
# 1    /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 2    /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 3                                                  NaN
# 4    /Users/cu135/Partners HealthCare Dropbox/Calvi...
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                     stimpyper_clinician_bilateral_vtas  \
# 0                                                  NaN
# 1    /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 2    /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 3                                                  NaN
# 4    /Users/cu135/Partners HealthCare Dropbox/Calvi...
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#      overlap_stimpyper_optimized_bilateral_vtas_vs_stimpyper_clinician_bilateral_vtas  \
# 0                                                  NaN
# 1                                             0.151932
# 2                                             0.181780
# 3                                                  NaN
# 4                                             0.288510
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#      Month_12_Delta_ADASMemImprove
# 0                              NaN
# 1                              6.0
# 2                              4.0
# 3                              NaN
# 4                              6.0
# ..                             ...
# 113                            NaN
# 114                            NaN
# 115                            NaN
# 116                            NaN
# 117                            NaN
#
# [118 rows x 141 columns]

# %% [markdown]
# # 01 - Preprocess Your Data

# %% [markdown]
# **Handle NANs**
# - Set drop_nans=True is you would like to remove NaNs from data
# - Provide a column name or a list of column names to remove NaNs from

# %%
data_df.columns
# Out:
# Index(['cohort_key', 'stimulation_modality', 'subject_id', 'subject',
#        'delta_adasmem', 'percent_improvement_adas', 'age', 'baseline_adas',
#        'followup_adas', 'atrophy_path',
#        ...
#        'data__yeo7__Limbic_FC', 'data__yeo7__Frontoparietal_A',
#        'data__yeo7__Frontoparietal_FC', 'data__yeo7__Default_A',
#        'data__yeo7__Default_FC', 'Month_12_Delta_ADASMem',
#        'stimpyper_optimized_bilateral_vtas',
#        'stimpyper_clinician_bilateral_vtas',
#        'overlap_stimpyper_optimized_bilateral_vtas_vs_stimpyper_clinician_bilateral_vtas',
#        'Month_12_Delta_ADASMemImprove'],
#       dtype='object', length=141)

# %%
drop_list = ['overlap_stimpyper_optimized_bilateral_vtas_vs_stimpyper_clinician_bilateral_vtas', 'Month_12_Delta_ADASMemImprove']

# %%
data_df = cal_palm.drop_nans_from_columns(columns_to_drop_from=drop_list)
data_df
# Out:
#     cohort_key stimulation_modality subject_id  subject  delta_adasmem  \
# 1   fornix_dbs                  DBS    sub-102    102.0            NaN
# 2   fornix_dbs                  DBS    sub-103    103.0            NaN
# 4   fornix_dbs                  DBS    sub-106    106.0            NaN
# 7   fornix_dbs                  DBS    sub-109    109.0            NaN
# 8   fornix_dbs                  DBS    sub-110    110.0            NaN
# 10  fornix_dbs                  DBS    sub-113    113.0            NaN
# 11  fornix_dbs                  DBS    sub-114    114.0            NaN
# 13  fornix_dbs                  DBS    sub-116    116.0            NaN
# 15  fornix_dbs                  DBS    sub-119    119.0            NaN
# 16  fornix_dbs                  DBS    sub-120    120.0            NaN
# 17  fornix_dbs                  DBS    sub-121    121.0            NaN
# 21  fornix_dbs                  DBS    sub-125    125.0            NaN
# 22  fornix_dbs                  DBS    sub-126    126.0            NaN
# 23  fornix_dbs                  DBS    sub-127    127.0            NaN
# 24  fornix_dbs                  DBS    sub-128    128.0            NaN
# 25  fornix_dbs                  DBS    sub-129    129.0            NaN
# 26  fornix_dbs                  DBS    sub-130    130.0            NaN
# 27  fornix_dbs                  DBS    sub-131    131.0            NaN
# 28  fornix_dbs                  DBS    sub-133    133.0            NaN
# 29  fornix_dbs                  DBS    sub-134    134.0            NaN
# 32  fornix_dbs                  DBS    sub-138    138.0            NaN
# 34  fornix_dbs                  DBS    sub-140    140.0            NaN
# 35  fornix_dbs                  DBS    sub-141    141.0            NaN
# 36  fornix_dbs                  DBS    sub-142    142.0            NaN
# 37  fornix_dbs                  DBS    sub-143    143.0            NaN
# 38  fornix_dbs                  DBS    sub-144    144.0            NaN
# 39  fornix_dbs                  DBS    sub-145    145.0            NaN
# 40  fornix_dbs                  DBS    sub-146    146.0            NaN
# 43  fornix_dbs                  DBS    sub-149    149.0            NaN
# 44  fornix_dbs                  DBS    sub-150    150.0            NaN
#
#     percent_improvement_adas   age  baseline_adas  followup_adas  \
# 1                  -0.363636  77.0           22.0           30.0
# 2                  -0.789474  76.0           19.0           34.0
# 4                  -0.384615  66.0           13.0           18.0
# 7                  -0.304348  72.0           23.0           30.0
# 8                  -0.846154  72.0           13.0           24.0
# 10                 -0.600000  69.0           15.0           24.0
# 11                 -0.161290  67.0           31.0           36.0
# 13                 -0.368421  67.0           19.0           26.0
# 15                 -0.812500  75.0           16.0           29.0
# 16                 -0.277778  78.0           18.0           23.0
# 17                 -0.043478  72.0           23.0           24.0
# 21                 -0.375000  73.0           16.0           22.0
# 22                 -1.000000  69.0           21.0           42.0
# 23                 -0.764706  74.0           17.0           30.0
# 24                 -0.208333  72.0           24.0           29.0
# 25                 -0.357143  69.0           28.0           38.0
# 26                 -0.071429  66.0           14.0           15.0
# 27                 -0.400000  68.0           20.0           28.0
# 28                  0.062500  74.0           16.0           15.0
# 29                  0.294118  66.0           17.0           12.0
# 32                 -0.095238  72.0           21.0           23.0
# 34                  0.181818  73.0           22.0           18.0
# 35                  0.000000  72.0           19.0           19.0
# 36                  0.055556  77.0           18.0           17.0
# 37                  0.062500  71.0           16.0           15.0
# 38                 -0.615385  79.0           13.0           21.0
# 39                  0.055556  74.0           18.0           17.0
# 40                 -0.545455  76.0           11.0           17.0
# 43                 -0.900000  77.0           10.0           19.0
# 44                  0.136364  71.0           22.0           19.0
#
#                                     atrophy_path  ... data__yeo7__Limbic_FC  \
# 1   files/fornix_dbs/sub-102/atrophy_path.nii.gz  ...             17.193963
# 2   files/fornix_dbs/sub-103/atrophy_path.nii.gz  ...             14.630112
# 4   files/fornix_dbs/sub-106/atrophy_path.nii.gz  ...             14.001423
# 7   files/fornix_dbs/sub-109/atrophy_path.nii.gz  ...             14.672969
# 8   files/fornix_dbs/sub-110/atrophy_path.nii.gz  ...             10.553576
# 10  files/fornix_dbs/sub-113/atrophy_path.nii.gz  ...             13.027328
# 11  files/fornix_dbs/sub-114/atrophy_path.nii.gz  ...             12.544391
# 13  files/fornix_dbs/sub-116/atrophy_path.nii.gz  ...             14.438465
# 15  files/fornix_dbs/sub-119/atrophy_path.nii.gz  ...             14.798770
# 16  files/fornix_dbs/sub-120/atrophy_path.nii.gz  ...              9.065647
# 17  files/fornix_dbs/sub-121/atrophy_path.nii.gz  ...             12.961704
# 21  files/fornix_dbs/sub-125/atrophy_path.nii.gz  ...             14.065466
# 22  files/fornix_dbs/sub-126/atrophy_path.nii.gz  ...             12.576462
# 23  files/fornix_dbs/sub-127/atrophy_path.nii.gz  ...             12.882170
# 24  files/fornix_dbs/sub-128/atrophy_path.nii.gz  ...             11.737279
# 25  files/fornix_dbs/sub-129/atrophy_path.nii.gz  ...             11.704208
# 26  files/fornix_dbs/sub-130/atrophy_path.nii.gz  ...             14.656723
# 27  files/fornix_dbs/sub-131/atrophy_path.nii.gz  ...             13.767324
# 28  files/fornix_dbs/sub-133/atrophy_path.nii.gz  ...             11.915475
# 29  files/fornix_dbs/sub-134/atrophy_path.nii.gz  ...              8.361774
# 32  files/fornix_dbs/sub-138/atrophy_path.nii.gz  ...             10.954208
# 34  files/fornix_dbs/sub-140/atrophy_path.nii.gz  ...             11.158829
# 35  files/fornix_dbs/sub-141/atrophy_path.nii.gz  ...              6.628213
# 36  files/fornix_dbs/sub-142/atrophy_path.nii.gz  ...             12.362469
# 37  files/fornix_dbs/sub-143/atrophy_path.nii.gz  ...             15.535123
# 38  files/fornix_dbs/sub-144/atrophy_path.nii.gz  ...             12.223678
# 39  files/fornix_dbs/sub-145/atrophy_path.nii.gz  ...             11.778804
# 40  files/fornix_dbs/sub-146/atrophy_path.nii.gz  ...             14.316388
# 43  files/fornix_dbs/sub-149/atrophy_path.nii.gz  ...             14.124832
# 44  files/fornix_dbs/sub-150/atrophy_path.nii.gz  ...             10.321920
#
#    data__yeo7__Frontoparietal_A  data__yeo7__Frontoparietal_FC  \
# 1                      0.408067                     -10.334266
# 2                      0.359400                      -9.882224
# 4                      0.245907                      -9.856519
# 7                      0.487859                      -8.579234
# 8                      0.550166                      -6.595370
# 10                     0.331613                      -8.402599
# 11                     0.202025                      -7.844056
# 13                     0.249966                      -9.495790
# 15                     0.471085                      -9.125177
# 16                     0.393024                      -3.341256
# 17                     0.284739                      -6.831010
# 21                     0.448053                      -7.414455
# 22                     0.348134                      -6.371322
# 23                     0.128904                      -8.250836
# 24                     0.141977                      -7.405529
# 25                     0.296620                      -6.551891
# 26                     0.325353                      -9.441089
# 27                     0.260018                      -7.667402
# 28                     0.165591                      -7.339472
# 29                     0.243683                      -3.003344
# 32                     0.282631                      -5.894442
# 34                     0.372856                      -4.303637
# 35                     0.037325                      -4.395648
# 36                     0.102303                      -8.956968
# 37                     0.313632                     -10.475451
# 38                     0.309928                      -9.092004
# 39                     0.300884                      -5.334722
# 40                     0.119093                      -8.963966
# 43                     0.356315                      -8.542617
# 44                     0.366285                      -4.865087
#
#     data__yeo7__Default_A  data__yeo7__Default_FC  Month_12_Delta_ADASMem  \
# 1                0.354756                3.755009                    -6.0
# 2                0.475581                4.449948                    -4.0
# 4                0.280630                4.013440                    -6.0
# 7                0.573334                6.605472                    -6.0
# 8                0.463215                5.124782                     3.0
# 10               0.296773                3.750337                   -14.0
# 11               0.326945                3.012296                    -7.0
# 13               0.364094                3.634277                    -5.0
# 15               0.480119                5.505290                    -1.0
# 16               0.476817               -0.092020                     NaN
# 17               0.331021                7.277957                    -4.0
# 21               0.574787                6.725270                     1.0
# 22               0.403552                5.379243                    -7.0
# 23               0.242445                3.805606                    -1.0
# 24               0.199106                3.986602                    -6.0
# 25               0.272389                5.997902                    -2.0
# 26               0.303829                5.026517                    -7.0
# 27               0.397915                3.665687                     0.0
# 28               0.146874                4.365381                    -5.0
# 29               0.239773                7.612947                     0.0
# 32               0.245005                4.874514                    -2.0
# 34               0.509624                7.877085                     1.0
# 35               0.061704                6.490425                   -20.0
# 36               0.158711                3.666245                     3.0
# 37               0.293071                9.522772                    -3.0
# 38               0.323981                1.979324                    -5.0
# 39               0.381694                5.100272                     2.0
# 40               0.221094                3.660381                     4.0
# 43               0.308670                3.883827                     2.0
# 44               0.448131                8.295561                    -8.0
#
#                    stimpyper_optimized_bilateral_vtas  \
# 1   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 2   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 4   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 7   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 8   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 10  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 11  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 13  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 15  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 16  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 17  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 21  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 22  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 23  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 24  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 25  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 26  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 27  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 28  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 29  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 32  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 34  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 35  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 36  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 37  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 38  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 39  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 40  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 43  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 44  /Users/cu135/Partners HealthCare Dropbox/Calvi...
#
#                    stimpyper_clinician_bilateral_vtas  \
# 1   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 2   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 4   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 7   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 8   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 10  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 11  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 13  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 15  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 16  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 17  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 21  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 22  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 23  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 24  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 25  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 26  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 27  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 28  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 29  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 32  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 34  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 35  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 36  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 37  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 38  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 39  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 40  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 43  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 44  /Users/cu135/Partners HealthCare Dropbox/Calvi...
#
#     overlap_stimpyper_optimized_bilateral_vtas_vs_stimpyper_clinician_bilateral_vtas  \
# 1                                            0.151932
# 2                                            0.181780
# 4                                            0.288510
# 7                                            0.200547
# 8                                            0.175703
# 10                                           0.225215
# 11                                           0.277243
# 13                                           0.212775
# 15                                           0.169371
# 16                                           0.127523
# 17                                           0.159058
# 21                                           0.133862
# 22                                           0.305554
# 23                                           0.122334
# 24                                           0.273711
# 25                                           0.143964
# 26                                           0.245811
# 27                                           0.194383
# 28                                           0.247488
# 29                                           0.127472
# 32                                           0.300055
# 34                                           0.159681
# 35                                           0.308682
# 36                                           0.263035
# 37                                           0.262403
# 38                                           0.185527
# 39                                           0.208501
# 40                                           0.091509
# 43                                           0.226914
# 44                                           0.093623
#
#     Month_12_Delta_ADASMemImprove
# 1                             6.0
# 2                             4.0
# 4                             6.0
# 7                             6.0
# 8                            -3.0
# 10                           11.0
# 11                            7.0
# 13                            5.0
# 15                            1.0
# 16                            0.0
# 17                            4.0
# 21                           -1.0
# 22                            7.0
# 23                            1.0
# 24                            6.0
# 25                            2.0
# 26                            7.0
# 27                            0.0
# 28                            5.0
# 29                            0.0
# 32                            2.0
# 34                           -1.0
# 35                           11.0
# 36                           -3.0
# 37                            3.0
# 38                            5.0
# 39                           -2.0
# 40                           -4.0
# 43                           -2.0
# 44                            8.0
#
# [30 rows x 141 columns]

# %% [markdown]
# Set the parameters for dropping rows

# %%
data_df.columns
# Out:
# Index(['cohort_key', 'stimulation_modality', 'subject_id', 'subject',
#        'delta_adasmem', 'percent_improvement_adas', 'age', 'baseline_adas',
#        'followup_adas', 'atrophy_path',
#        ...
#        'data__yeo7__Limbic_FC', 'data__yeo7__Frontoparietal_A',
#        'data__yeo7__Frontoparietal_FC', 'data__yeo7__Default_A',
#        'data__yeo7__Default_FC', 'Month_12_Delta_ADASMem',
#        'stimpyper_optimized_bilateral_vtas',
#        'stimpyper_clinician_bilateral_vtas',
#        'overlap_stimpyper_optimized_bilateral_vtas_vs_stimpyper_clinician_bilateral_vtas',
#        'Month_12_Delta_ADASMemImprove'],
#       dtype='object', length=141)

# %%
# m1 = data_df['cohens_D_redo_residual'] < -0.1
# m2 = data_df['CNM_Damage_Roi_old'] > 0
# m3 = m1 & m2
# data_df['mask'] = m3

# %%
column = 'mask'  # The column you'd like to evaluate
condition = 'equal'  # Thecondition to check ('equal', 'above', 'below', 'not')
value = True # The value to compare against

# %%
data_df, other_df = cal_palm.drop_rows_based_on_value(column, condition, value)
data_df

# %% [markdown]
# Regress out a Covariate

# %%
for col in data_df.columns:
    print(col)

# %%
dependent_variable_list = ['cohens_D_redo']
regressors = ['Stimulation_site', 'Frequency']

# %%
for col in regressors:
    if data_df[col].dtype == 'O':  # object/categorical
        data_df[col] = data_df[col].fillna(data_df[col].mode()[0])
    else:  # numeric
        data_df[col] = data_df[col].fillna(data_df[col].mean())
data_df[regressors].isna().sum()

# %%
from calvin_utils.statistical_utils.regression_utils import RegressOutCovariates
data_df, adjusted_dep_vars_list = RegressOutCovariates.run(df=data_df, dependent_variable_list=dependent_variable_list, covariates_list=regressors)
print(adjusted_dep_vars_list)

# %% [markdown]
# **Standardize Data**
# - Enter Columns you Don't want to standardize into a list

# %%
data_df.columns

# %%
# Remove anything you don't want to standardize
# cols_not_to_standardize = ['Overall_Cognition_Cohen_s_D']

# %%
# data_df = cal_palm.standardize_columns(cols_not_to_standardize)
data_df

# %% [markdown]
# Misc Filtering

# %%
# data_df = data_df[data_df['Pre_Post_Memory_Effect_Size__Cohen_s_D_'].abs() <= 10]
q1 = data_df['cohens_D_redo_residual'].quantile(0.25)
q3 = data_df['cohens_D_redo_residual'].quantile(0.75)
iqr = q3 - q1
data_df['outlier'] = data_df['cohens_D_redo_residual'] > (q3 + 1.5*iqr)
data_df['outlier'] = data_df['cohens_D_redo_residual'] < (q1 - 1.5*iqr)
data_df['outlier']

# %% [markdown]
# # 02 - Perform Basic Correlation

# %%
data_df.columns
# Out:
# Index(['cohort_key', 'stimulation_modality', 'subject_id', 'subject',
#        'delta_adasmem', 'percent_improvement_adas', 'age', 'baseline_adas',
#        'followup_adas', 'atrophy_path',
#        ...
#        'data__yeo7__Limbic_FC', 'data__yeo7__Frontoparietal_A',
#        'data__yeo7__Frontoparietal_FC', 'data__yeo7__Default_A',
#        'data__yeo7__Default_FC', 'Month_12_Delta_ADASMem',
#        'stimpyper_optimized_bilateral_vtas',
#        'stimpyper_clinician_bilateral_vtas',
#        'overlap_stimpyper_optimized_bilateral_vtas_vs_stimpyper_clinician_bilateral_vtas',
#        'Month_12_Delta_ADASMemImprove'],
#       dtype='object', length=141)

# %%
x_col = 'overlap_stimpyper_optimized_bilateral_vtas_vs_stimpyper_clinician_bilateral_vtas'
y_col = 'Month_12_Delta_ADASMemImprove'

# %%
from calvin_utils.statistical_utils.scatterplot import simple_scatter
simple_scatter(data_df, x_col, y_col, '', 
               x_label="Spatial Correlation",
               y_label="Cognitive Outcome (Adj. Cohen's D)",
               out_dir=out_dir, flip_axes=False)
# Out:
# <Axes: xlabel='Spatial Correlation', ylabel="Cognitive Outcome (Adj. Cohen's D)">

# %%
import numpy as np 
data_df['dlpfc_connectivity'] = np.where(data_df['CNM_Damage_Roi_old']>0, 'Positive', 'Negative')

# %%
from calvin_utils.plotting_utils.simple_box_plot import SimpleBoxPlotPair

plotter = SimpleBoxPlotPair(data_df,
                            group_col="dlpfc_connectivity",
                            value_col='cohens_D_redo_residual',
                            dataset_name='dlPFC',
                            out_dir=out_dir,
                            xlabel='Spatial Correlation',
                            ylabel="Cognitive Outcome (Adj. Cohen's D)",
                            figsize=(5,6)).run()

# %% [markdown]
# Check p-values with Permutation

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
spearman = []
pearson = []

x = data_df['cohens_D_redo_residual']
y = data_df['CNM_Damage_Roi_old']

rho_real, _ = spearmanr(x,y)
r_real, _  = pearsonr(x,y)

for i in range(0,10000):
    x = data_df['cohens_D_redo_residual']
    y = np.random.choice(data_df['CNM_Damage_Roi_old'], size=len(data_df['CNM_Damage_Roi_old']), replace=False)
    rho, _ = spearmanr(x,y)
    r, _ = pearsonr(x,y)
    spearman.append(rho)
    pearson.append(r)

rho_p = np.mean(rho_real < np.array(spearman))
r_p = np.mean(r_real < np.array(pearson))

print(rho_p, r_p)

# %%
r_real

# %%
data_df.columns

# %%
import itertools
from scipy.stats import pearsonr, spearmanr
from calvin_utils.statistical_utils.regression_utils import RegressOutCovariates

scores = ['score', 0, 0]
dependent_variable_list = ['cohens_D_redo']
covariate_options = ['DOI', 'RCT_Design', 'Age_range', 'CDR', 'Active_N', 'Sham_N',
       'Mean_Age', 'Active_Age', 'Sham_Age', 'Active_M_F', 'Sham_M_F',
       'Active_Education__Yrs_', 'Sham_Education__Yrs_',
       'Active_AD_Treatment_Proportion', 'Diagnosis', 'Diagnostic_Criteria',
       'Stim_Type', 'Frequency', 'Intensity', 'Navigation',
       'Total_Pulses_session', 'session', 'Total_pulses',
       'Overall_Cognition_Test', 'Redo_test', 'Verbal_Memory_Test', 'Memory_Cohen_s_D',
       'Stimulation_site', 'Stim_Coordinate', 'Included', 'Exclusion_Reason', 'subject']
for combination in itertools.combinations(covariate_options, 3):
    covariates = list(combination)
    data_df, adjusted_dep_vars_list = RegressOutCovariates.run(df=data_df, dependent_variable_list=dependent_variable_list, covariates_list=covariates)
    res_col = adjusted_dep_vars_list[0]
    r, p = spearmanr(data_df.loc[:, res_col], data_df.loc[:, 'CNM_Damage_Roi_old'], alternative='two-sided')
    if r > scores[1]:
        scores[0] = combination
        scores[1] = r
        scores[2] = p

# %%
print(scores)

# %% [markdown]
# # Correlate Variable with All Other Variables

# %%
x_col = 'flipped_lesions_all_datasets_weighted_avg_r_map_cosine'

# %%
from calvin_utils.statistical_utils.correlation_barplot import CorrelationBarPlot
plotter = CorrelationBarPlot(data_df, x_col=x_col, method="spearman")
corr_series = plotter.run(save_path=None)

# %% [markdown]
# Focus on correlations above a threhsold

# %%
strong_corrs = plotter.plot_threshold(0.3)      # |r| ≥ 0.4 plot
