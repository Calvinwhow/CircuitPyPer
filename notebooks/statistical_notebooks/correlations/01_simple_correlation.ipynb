# %% [markdown]
# # Run Correlation-Based Analyses
#
# ### Authors: Calvin Howard.
#
# #### Last updated: July 6, 2023
#
# Use this to assess if a correlation between a dependent variable and an independent variable is statistically significant using permutation analysis.
#
# Further, follow this up with a contrast analysis which sees which categorical variables have significantly different correlations from each other.
#
# Notes:
# - To best use this notebook, you should be familar with mixed effects models

# %% [markdown]
# # 00 - Import CSV with All Data
# **The CSV is expected to be in this format**
# - ID and absolute paths to niftis are critical
# ```
# +-----+----------------------------+--------------+--------------+--------------+
# | ID  | Nifti_File_Path            | Covariate_1  | Covariate_2  | Covariate_3  |
# +-----+----------------------------+--------------+--------------+--------------+
# | 1   | /path/to/file1.nii.gz      | 0.5          | 1.2          | 3.4          |
# | 2   | /path/to/file2.nii.gz      | 0.7          | 1.4          | 3.1          |
# | 3   | /path/to/file3.nii.gz      | 0.6          | 1.5          | 3.5          |
# | 4   | /path/to/file4.nii.gz      | 0.9          | 1.1          | 3.2          |
# | ... | ...                        | ...          | ...          | ...          |
# +-----+----------------------------+--------------+--------------+--------------+
# ```

# %%
# Specify the path to your CSV file containing NIFTI paths
input_csv_path = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/05c_Howard_MetaAlzheimerReview_DBS-TMS_Coordinates/metadata/master_list.xlsx'
sheet = 'Sheet1' #'master_list'

# %%
# Specify where you want to save your results to
out_dir = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/ccm_memory/results/tms_meta_analysis/dlpfc_alone_nodbs'

# %%
from calvin_utils.permutation_analysis_utils.statsmodels_palm import CalvinStatsmodelsPalm
# Instantiate the PalmPrepararation class
cal_palm = CalvinStatsmodelsPalm(input_csv_path=input_csv_path, output_dir=out_dir, sheet=sheet)
# Call the process_nifti_paths method
data_df = cal_palm.read_and_display_data()
data_df
# Out:
#                             Study  \
# 0                 Wu et al., 2024
# 1           Moussavi et al., 2024
# 2            Cotelli et al., 2011
# 3       Ahmed et al., 2012 (1 Hz)
# 4                 Li et al., 2021
# 5                Wei et al., 2022
# 6               Koch et al., 2022
# 7                Jia et al., 2021
# 8    Saitoh et al., 2022 (90%RTM)
# 9               Kuhn et al., 2015
# 10  Saitoh et al., 2022 (120%RTM)
# 11                Hu et al., 2022
# 12                Wu et al., 2022
# 13              Jung et al., 2025
# 14               Liu et al., 2022
# 15               Yao et al., 2022
# 16        Rutherford et al., 2015
# 17              Koch et al., 2025
# 18            Padala et al., 2020
# 19                Wu et al., 2015
# 20            Lozano et al., 2016
# 21               Qin et al., 2023
# 22              Koch et al., 2018
# 23     Ahmed et al., 2012 (20 Hz)
# 24              Zhao et al., 2017
# 25             Zhang et al., 2019
# 26         Turriziani et al. 2019
# 27           Bentwich et al. 2011
# 28             Nguyen et al. 2017
# 29                 Wu et al. 2020
# 30                Lee et al. 2015
# 31             Haffen et al. 2012
# 32              Cheng et al. 2022
# 33              Rabey et al. 2013
# 34            Sabbagh et al. 2020
# 35           Velioglu et al. 2021
#
#                                                  DOI   RCT_Design  \
# 0                         10.1136/gpsych-2023-101106     Parallel
# 1                       10.1016/j.neurot.2024.e00331     Parallel
# 2                           10.1136/jnnp.2009.197848     Parallel
# 3                          10.1007/s00415-011-6128-4     Parallel
# 4                          10.1016/j.brs.2021.01.012     Parallel
# 5                     10.1016/j.psychres.2022.114721     Parallel
# 6                              10.1093/brain/awac285     Parallel
# 7                          10.3389/fnagi.2021.693611     Parallel
# 8                          10.3389/fnagi.2022.993306     Parallel
# 9                 https://doi.org/10.1038/mp.2014.32    Crossover
# 10                         10.3389/fnagi.2022.993306     Parallel
# 11                         10.1016/j.brs.2022.11.009     Parallel
# 12                         10.1016/j.brs.2021.11.007     Parallel
# 13                 10.1001/jamanetworkopen.2024.9220     Parallel
# 14                            10.1093/cercor/bhab371     Parallel
# 15                         10.1016/j.brs.2022.06.004     Parallel
# 16                                10.4137/JEN.S24004    Crossover
# 17                        10.1186/s13195-025-01709-7     Parallel
# 18                    10.1016/j.psychres.2017.12.063     Parallel
# 19                  10.11919/j.issn.1002-0829.215107     Parallel
# 20                https://doi.org/10.3233/JAD-160017     Parallel
# 21                        10.3389/fncir.2023.1202671     Parallel
# 22  https://doi.org/10.1016/j.neuroimage.2017.12.048          NaN
# 23                         10.1007/s00415-011-6128-4     Parallel
# 24                         10.18632/oncotarget.13060     Parallel
# 25                        10.1007/s00702-019-02022-y     Parallel
# 26                                10.3233/JAD-190888     Parallel
# 27                      10.1097/YCT.0000000000000286  Case Series
# 28                      10.1016/j.neucli.2017.01.001       Single
# 29                         10.1016/j.brs.2019.12.020       Single
# 30                          10.3988/jcn.2016.12.1.57     Parallel
# 31                         10.1016/j.brs.2011.03.003  Case Report
# 32                                10.3233/JAD-210349     Parallel
# 33                         10.1007/s00702-012-0902-z     Parallel
# 34                        10.1016/j.jalz.2019.08.197          NaN
# 35                         10.1016/j.nlm.2021.107410          NaN
#
#                    Age_range                                   CDR  Active_N  \
# 0                        ≧50                                 0.5-2      20.0
# 1                        >55                                   1∼2      53.0
# 2                        NaN                                   NaN       5.0
# 3                      60-82                                   NaN      15.0
# 4                        NaN                                   NaN      37.0
# 5                      55–85                                 0.5–2      29.0
# 6                      50–85                                 0.5–1      25.0
# 7                      55–85                                 0.5–2      35.0
# 8                        NaN                                   NaN      13.0
# 9                      57-90                                  <0.5       6.0
# 10  60–93 (participant data)                                   1–2      15.0
# 11                     60–90                                     2      21.0
# 12                       ≧50                                    ≦2      24.0
# 13                     55-90                                 0.5-2      18.0
# 14                     50–85                                 0.5–1      25.0
# 15                     60–80  Active:1.07 ± 0.53 Sham: 1.20 ± 0.59      15.0
# 16                     57-87                                   NaN      10.0
# 17                     57-90                                 0.5–1      27.0
# 18                       ≧55                                   NaN       9.0
# 19                     60–80                                   NaN      26.0
# 20                       >65                                   0.5      30.0
# 21                       NaN                                    ≦2      26.0
# 22                       >65                                 0.5–1      14.0
# 23                     60-82                                   NaN      15.0
# 24                       NaN                                   1–2      17.0
# 25                       NaN                                   NaN      15.0
# 26                       NaN                                   NaN      12.0
# 27                       NaN                                   NaN       NaN
# 28                       NaN                                   NaN       NaN
# 29                       NaN                                   NaN       NaN
# 30                       NaN                                   NaN       NaN
# 31                       NaN                                   NaN       NaN
# 32                       >55                                   NaN      13.0
# 33                       NaN                                   NaN       NaN
# 34                       NaN                                   NaN       NaN
# 35                       NaN                                   NaN       NaN
#
#     Sham_N  Mean_Age    Active_Age      Sham_Age  ...  \
# 0     22.0      67.0   66.8 ± 8.84  65.32 ± 7.31  ...
# 1     51.0      73.0    73.3 ± 6.9      75 ± 9.1  ...
# 2      5.0      71.0    71.2 ± 6.1    74.4 ± 3.8  ...
# 3     15.0      65.0    65.9 ± 5.9    68.3 ± 4.9  ...
# 4     38.0      65.0  65.97 ± 8.47  64.58 ± 7.88  ...
# 5     27.0      70.0     70 ± 8.68  71.67 ± 7.16  ...
# 6     25.0      75.0      75 ± 5.6    72.3 ± 7.2  ...
# 7     34.0      71.0  71.41 ± 8.85  73.41 ± 7.73  ...
# 8      NaN      77.0          77.2           NaN  ...
# 9      NaN      69.0    69.5 ± 7.7           NaN  ...
# 10    12.0      76.0          76.2          75.8  ...
# 11    21.0      76.0  76.86 ± 6.07  75.33 ± 5.73  ...
# 12    23.0      66.0  66.46 ± 8.25  66.35 ± 7.99  ...
# 13    12.0      69.0    69.8 ± 9.1    69.8 ± 9.1  ...
# 14    12.0      67.0  67.28 ± 7.74   72.08 ± 7.3  ...
# 15    12.0      63.0  63.87 ± 6.85   67.6 ± 7.88  ...
# 16    10.0      57.0            57            57  ...
# 17    21.0      74.0      74 ± 5.1   71.2 ± 5.11  ...
# 18    11.0      74.0    74.3 ± 5.7    79.6 ± 7.7  ...
# 19    26.0      71.0    71.4 ± 4.9    71.9 ± 4.8  ...
# 20    15.0      69.0    69.8 ± 8.1    67.8 ± 7.7  ...
# 21    25.0      67.0  67.36 ± 6.98  66.25 ± 8.07  ...
# 22     NaN      70.0      70 ± 5.1           NaN  ...
# 23    15.0      65.0    65.9 ± 5.9    68.3 ± 4.9  ...
# 24    13.0      69.0    69.3 ± 5.8    71.4 ± 5.2  ...
# 25    15.0      69.0     69 ± 8.19  68.54 ± 7.93  ...
# 26    12.0       NaN           NaN           NaN  ...
# 27     NaN       NaN           NaN           NaN  ...
# 28     NaN       NaN           NaN           NaN  ...
# 29     NaN       NaN           NaN           NaN  ...
# 30     NaN       NaN           NaN           NaN  ...
# 31     NaN       NaN           NaN           NaN  ...
# 32    13.0      70.9    70.2 (7.6)    71.3 (7.6)  ...
# 33     NaN       NaN           NaN           NaN  ...
# 34     NaN       NaN           NaN           NaN  ...
# 35     NaN       NaN           NaN           NaN  ...
#
#                                      Stimulation_site  dlpfc  \
# 0                                          Left DLPFC    1.0
# 1                                     Bilateral DLPFC    1.0
# 2                                          Left DLPFC    1.0
# 3                                     Bilateral DLPFC    1.0
# 4                                          Left DLPFC    1.0
# 5                      Left lateral parietal location    0.0
# 6                                           Precuneus    0.0
# 7                          Left lateral parietal site    0.0
# 8                                     Bilateral DLPFC    1.0
# 9                                       Bilateral NBM    0.0
# 10                                    Bilateral DLPFC    1.0
# 11                            Bilateral angular gyrus    0.0
# 12                                         Left DLPFC    1.0
# 13                         Left lateral parietal site    0.0
# 14                                Bilateral dorsal AG    0.0
# 15                               Bilateral cerebellum    0.0
# 16                                    Bilateral DLPFC    1.0
# 17                                          Precuneus    0.0
# 18                                         Left DLPFC    1.0
# 19                                         Left DLPFC    1.0
# 20                                   Bilateral Fornix    0.0
# 21                  Left DLPFC, left lateral temporal    1.0
# 22                                          Precuneus    0.0
# 23                                    Bilateral DLPFC    1.0
# 24  Parietal lobe (P3/P4) and posterior temporal l...    0.0
# 25                  Left DLPFC, left lateral temporal    1.0
# 26                                         Left DLPFC    1.0
# 27                                                NaN    NaN
# 28                                                NaN    NaN
# 29                                                NaN    NaN
# 30                                                NaN    NaN
# 31                                                NaN    NaN
# 32                                         Left DLPFC    1.0
# 33                                                NaN    NaN
# 34                                                NaN    NaN
# 35                                      Parietal Lobe    0.0
#
#                              Stim_Coordinate Included  \
# 0                              [-38, 44, 26]      1.0
# 1            [-41.1, 36, 38], [41.1, 36, 38]      1.0
# 2                              [-29, 23, 59]      1.0
# 3        [-22.7, 38.9, 44], [22.7, 38.9, 44]      1.0
# 4                                [-44,40,29]      1.0
# 5                             [-47, -68, 36]      1.0
# 6                               [0, -70, 44]      1.0
# 7                             [-47, -68, 36]      1.0
# 8                [-29, 23, 59], [29, 23, 59]      1.0
# 9        [-20, -7.1, -8.6], [20, -7.1, -8.6]      1.0
# 10               [-29, 23, 59], [29, 23, 59]      1.0
# 11             [63, -53, 27], [-63, -53, 27]      1.0
# 12                             [-38, 44, 26]      1.0
# 13                      [-47.3, -68.5, 36.2]      1.0
# 14             [-61, -51, 39], [61, -51, 39]      1.0
# 15           [30, -88, -35], [-30, -88, -35]      1.0
# 16                             [-29, 23, 59]      1.0
# 17                              [0, -70, 44]      1.0
# 18                             [-29, 23, 59]      1.0
# 19                             [-29, 23, 59]      1.0
# 20           [-1.3, 2.8, -1], [1.3, 2.8, -1]      1.0
# 21               [-44,40,29], [-69, -8, -10]      0.0
# 22                              [0, -70, 44]      0.0
# 23       [-22.7, 38.9, 44], [22.7, 38.9, 44]      0.0
# 24  [-39.5, -76.3, 47.4], [59.3, -67.3, 3.8]      0.0
# 25               [-35,24,48], [-69, -8, -10]      0.0
# 26               [-29, 23, 59], [29, 23, 59]      0.0
# 27                             [-29, 23, 59]      0.0
# 28                                       NaN      0.0
# 29                                       NaN      0.0
# 30                                       NaN      0.0
# 31                                       NaN      0.0
# 32               [-35,24,48], [-69, -8, -10]      0.0
# 33                                       NaN      0.0
# 34                                       NaN      0.0
# 35                            [-29, -49, 60]      NaN
#
#                        Exclusion_Reason  \
# 0                                  iTBS
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                           no sham arm
# 10                                  NaN
# 11                                  NaN
# 12                                 iTBS
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16               Duplicated in Moussavi
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                  NaN
# 21                           Multifocal
# 22                           Duplicated
# 23                        low frequency
# 24                           Multifocal
# 25                           Multifocal
# 26  Low frequency, no general cognition
# 27                          Case Series
# 28                         Uncontrolled
# 29                         Uncontrolled
# 30                           Multifocal
# 31                          Case Report
# 32            No general cognitive test
# 33                           multifocal
# 34        Variable multifocal stim site
# 35                                  NaN
#
#                                              roi_path  \
# 0   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 1   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 2   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 3   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 4   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 5   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 6   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 7   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 8   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 9   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 10  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 11  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 12  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 13  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 14  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 15  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 16  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 17  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 18  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 19  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 20  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 21  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 22  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 23  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 24  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 25  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
#
#                                          roi_path_old  \
# 0                                                 NaN
# 1   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 2   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 3                                                 NaN
# 4   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 5   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 6   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 7   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 8   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 9   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 10  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 11  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 12  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 13  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 14  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 15  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 16                                                NaN
# 17  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 18  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 19  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 20  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 21                                                NaN
# 22  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 23                                                NaN
# 24  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
#
#                           subject CNM_Damage_Roi_old CNM_Damage_Roi_new
# 0                 Wu_et_al___2024          -0.685000          -0.681262
# 1           Moussavi_et_al___2024          -0.369729          -0.370000
# 2            Cotelli_et_al___2011          -0.510000           0.410000
# 3       Ahmed_et_al___2012__1_Hz_           0.430000           0.430000
# 4                 Li_et_al___2021          -0.615157          -0.620000
# 5                Wei_et_al___2022           0.620000           0.610000
# 6               Koch_et_al___2022           0.545000           0.545000
# 7                Jia_et_al___2021           0.605000           0.610000
# 8    Saitoh_et_al___2022__90_RTM_           0.353568           0.353000
# 9               Kuhn_et_al___2015           0.045051           0.451000
# 10  Saitoh_et_al___2022__120_RTM_           0.333408           0.346747
# 11                Hu_et_al___2022           0.370000           0.370000
# 12                Wu_et_al___2022          -0.685000          -0.690000
# 13              Jung_et_al___2025           0.602000           0.605000
# 14               Liu_et_al___2022           0.210017           0.215000
# 15               Yao_et_al___2022           0.380000           0.385000
# 16        Rutherford_et_al___2015           0.415073           0.415073
# 17              Koch_et_al___2025           0.550000           0.550000
# 18            Padala_et_al___2020           0.330822           0.415073
# 19                Wu_et_al___2015           0.330822           0.420000
# 20            Lozano_et_al___2016           0.590000           0.590000
# 21               Qin_et_al___2023          -0.487645          -0.487645
# 22              Koch_et_al___2018           0.540000           0.540000
# 23      Ahmed_et_al___2012__1_Hz_           0.430000           0.430000
# 24              Zhao_et_al___2017           0.200000           0.200000
# 25             Zhang_et_al___2019          -0.487645          -0.487645
# 26                            NaN                NaN                NaN
# 27                            NaN                NaN                NaN
# 28                            NaN                NaN                NaN
# 29                            NaN                NaN                NaN
# 30                            NaN          -0.487645          -0.487645
# 31                            NaN                NaN                NaN
# 32                            NaN          -0.487645          -0.487645
# 33                            NaN                NaN                NaN
# 34                            NaN                NaN                NaN
# 35                            NaN                NaN                NaN
#
# [36 rows x 40 columns]

# %% [markdown]
# # 01 - Preprocess Your Data

# %% [markdown]
# **Handle NANs**
# - Set drop_nans=True is you would like to remove NaNs from data
# - Provide a column name or a list of column names to remove NaNs from

# %%
data_df.columns
# Out:
# Index(['Study', 'DOI', 'RCT_Design', 'Age_range', 'CDR', 'Active_N', 'Sham_N',
#        'Mean_Age', 'Active_Age', 'Sham_Age', 'Active_M_F', 'Sham_M_F',
#        'Active_Education__Yrs_', 'Sham_Education__Yrs_',
#        'Active_AD_Treatment_Proportion', 'Diagnosis', 'Diagnostic_Criteria',
#        'Stim_Type', 'Frequency', 'Intensity', 'Navigation',
#        'Total_Pulses_session', 'session', 'Total_pulses',
#        'Overall_Cognition_Test', 'Overall_Cognition_Cohen_s_D', 'Redo_test',
#        'cohens_D_redo', 'Verbal_Memory_Test', 'Memory_Cohen_s_D',
#        'Stimulation_site', 'dlpfc', 'Stim_Coordinate', 'Included',
#        'Exclusion_Reason', 'roi_path', 'roi_path_old', 'subject',
#        'CNM_Damage_Roi_old', 'CNM_Damage_Roi_new'],
#       dtype='object')

# %%
drop_list = ['CNM_Damage_Roi_old', 'cohens_D_redo','Included']

# %%
data_df = cal_palm.drop_nans_from_columns(columns_to_drop_from=drop_list)
data_df
# Out:
#                             Study  \
# 0                 Wu et al., 2024
# 1           Moussavi et al., 2024
# 2            Cotelli et al., 2011
# 3       Ahmed et al., 2012 (1 Hz)
# 4                 Li et al., 2021
# 5                Wei et al., 2022
# 6               Koch et al., 2022
# 7                Jia et al., 2021
# 8    Saitoh et al., 2022 (90%RTM)
# 9               Kuhn et al., 2015
# 10  Saitoh et al., 2022 (120%RTM)
# 11                Hu et al., 2022
# 12                Wu et al., 2022
# 13              Jung et al., 2025
# 14               Liu et al., 2022
# 15               Yao et al., 2022
# 16        Rutherford et al., 2015
# 17              Koch et al., 2025
# 18            Padala et al., 2020
# 19                Wu et al., 2015
# 20            Lozano et al., 2016
# 21               Qin et al., 2023
# 22              Koch et al., 2018
# 24              Zhao et al., 2017
# 25             Zhang et al., 2019
# 30                Lee et al. 2015
#
#                                                  DOI RCT_Design  \
# 0                         10.1136/gpsych-2023-101106   Parallel
# 1                       10.1016/j.neurot.2024.e00331   Parallel
# 2                           10.1136/jnnp.2009.197848   Parallel
# 3                          10.1007/s00415-011-6128-4   Parallel
# 4                          10.1016/j.brs.2021.01.012   Parallel
# 5                     10.1016/j.psychres.2022.114721   Parallel
# 6                              10.1093/brain/awac285   Parallel
# 7                          10.3389/fnagi.2021.693611   Parallel
# 8                          10.3389/fnagi.2022.993306   Parallel
# 9                 https://doi.org/10.1038/mp.2014.32  Crossover
# 10                         10.3389/fnagi.2022.993306   Parallel
# 11                         10.1016/j.brs.2022.11.009   Parallel
# 12                         10.1016/j.brs.2021.11.007   Parallel
# 13                 10.1001/jamanetworkopen.2024.9220   Parallel
# 14                            10.1093/cercor/bhab371   Parallel
# 15                         10.1016/j.brs.2022.06.004   Parallel
# 16                                10.4137/JEN.S24004  Crossover
# 17                        10.1186/s13195-025-01709-7   Parallel
# 18                    10.1016/j.psychres.2017.12.063   Parallel
# 19                  10.11919/j.issn.1002-0829.215107   Parallel
# 20                https://doi.org/10.3233/JAD-160017   Parallel
# 21                        10.3389/fncir.2023.1202671   Parallel
# 22  https://doi.org/10.1016/j.neuroimage.2017.12.048        NaN
# 24                         10.18632/oncotarget.13060   Parallel
# 25                        10.1007/s00702-019-02022-y   Parallel
# 30                          10.3988/jcn.2016.12.1.57   Parallel
#
#                    Age_range                                   CDR  Active_N  \
# 0                        ≧50                                 0.5-2      20.0
# 1                        >55                                   1∼2      53.0
# 2                        NaN                                   NaN       5.0
# 3                      60-82                                   NaN      15.0
# 4                        NaN                                   NaN      37.0
# 5                      55–85                                 0.5–2      29.0
# 6                      50–85                                 0.5–1      25.0
# 7                      55–85                                 0.5–2      35.0
# 8                        NaN                                   NaN      13.0
# 9                      57-90                                  <0.5       6.0
# 10  60–93 (participant data)                                   1–2      15.0
# 11                     60–90                                     2      21.0
# 12                       ≧50                                    ≦2      24.0
# 13                     55-90                                 0.5-2      18.0
# 14                     50–85                                 0.5–1      25.0
# 15                     60–80  Active:1.07 ± 0.53 Sham: 1.20 ± 0.59      15.0
# 16                     57-87                                   NaN      10.0
# 17                     57-90                                 0.5–1      27.0
# 18                       ≧55                                   NaN       9.0
# 19                     60–80                                   NaN      26.0
# 20                       >65                                   0.5      30.0
# 21                       NaN                                    ≦2      26.0
# 22                       >65                                 0.5–1      14.0
# 24                       NaN                                   1–2      17.0
# 25                       NaN                                   NaN      15.0
# 30                       NaN                                   NaN       NaN
#
#     Sham_N  Mean_Age    Active_Age      Sham_Age  ...  \
# 0     22.0      67.0   66.8 ± 8.84  65.32 ± 7.31  ...
# 1     51.0      73.0    73.3 ± 6.9      75 ± 9.1  ...
# 2      5.0      71.0    71.2 ± 6.1    74.4 ± 3.8  ...
# 3     15.0      65.0    65.9 ± 5.9    68.3 ± 4.9  ...
# 4     38.0      65.0  65.97 ± 8.47  64.58 ± 7.88  ...
# 5     27.0      70.0     70 ± 8.68  71.67 ± 7.16  ...
# 6     25.0      75.0      75 ± 5.6    72.3 ± 7.2  ...
# 7     34.0      71.0  71.41 ± 8.85  73.41 ± 7.73  ...
# 8      NaN      77.0          77.2           NaN  ...
# 9      NaN      69.0    69.5 ± 7.7           NaN  ...
# 10    12.0      76.0          76.2          75.8  ...
# 11    21.0      76.0  76.86 ± 6.07  75.33 ± 5.73  ...
# 12    23.0      66.0  66.46 ± 8.25  66.35 ± 7.99  ...
# 13    12.0      69.0    69.8 ± 9.1    69.8 ± 9.1  ...
# 14    12.0      67.0  67.28 ± 7.74   72.08 ± 7.3  ...
# 15    12.0      63.0  63.87 ± 6.85   67.6 ± 7.88  ...
# 16    10.0      57.0            57            57  ...
# 17    21.0      74.0      74 ± 5.1   71.2 ± 5.11  ...
# 18    11.0      74.0    74.3 ± 5.7    79.6 ± 7.7  ...
# 19    26.0      71.0    71.4 ± 4.9    71.9 ± 4.8  ...
# 20    15.0      69.0    69.8 ± 8.1    67.8 ± 7.7  ...
# 21    25.0      67.0  67.36 ± 6.98  66.25 ± 8.07  ...
# 22     NaN      70.0      70 ± 5.1           NaN  ...
# 24    13.0      69.0    69.3 ± 5.8    71.4 ± 5.2  ...
# 25    15.0      69.0     69 ± 8.19  68.54 ± 7.93  ...
# 30     NaN       NaN           NaN           NaN  ...
#
#                                      Stimulation_site  dlpfc  \
# 0                                          Left DLPFC    1.0
# 1                                     Bilateral DLPFC    1.0
# 2                                          Left DLPFC    1.0
# 3                                     Bilateral DLPFC    1.0
# 4                                          Left DLPFC    1.0
# 5                      Left lateral parietal location    0.0
# 6                                           Precuneus    0.0
# 7                          Left lateral parietal site    0.0
# 8                                     Bilateral DLPFC    1.0
# 9                                       Bilateral NBM    0.0
# 10                                    Bilateral DLPFC    1.0
# 11                            Bilateral angular gyrus    0.0
# 12                                         Left DLPFC    1.0
# 13                         Left lateral parietal site    0.0
# 14                                Bilateral dorsal AG    0.0
# 15                               Bilateral cerebellum    0.0
# 16                                    Bilateral DLPFC    1.0
# 17                                          Precuneus    0.0
# 18                                         Left DLPFC    1.0
# 19                                         Left DLPFC    1.0
# 20                                   Bilateral Fornix    0.0
# 21                  Left DLPFC, left lateral temporal    1.0
# 22                                          Precuneus    0.0
# 24  Parietal lobe (P3/P4) and posterior temporal l...    0.0
# 25                  Left DLPFC, left lateral temporal    1.0
# 30                                                NaN    NaN
#
#                              Stim_Coordinate Included        Exclusion_Reason  \
# 0                              [-38, 44, 26]      1.0                    iTBS
# 1            [-41.1, 36, 38], [41.1, 36, 38]      1.0                     NaN
# 2                              [-29, 23, 59]      1.0                     NaN
# 3        [-22.7, 38.9, 44], [22.7, 38.9, 44]      1.0                     NaN
# 4                                [-44,40,29]      1.0                     NaN
# 5                             [-47, -68, 36]      1.0                     NaN
# 6                               [0, -70, 44]      1.0                     NaN
# 7                             [-47, -68, 36]      1.0                     NaN
# 8                [-29, 23, 59], [29, 23, 59]      1.0                     NaN
# 9        [-20, -7.1, -8.6], [20, -7.1, -8.6]      1.0             no sham arm
# 10               [-29, 23, 59], [29, 23, 59]      1.0                     NaN
# 11             [63, -53, 27], [-63, -53, 27]      1.0                     NaN
# 12                             [-38, 44, 26]      1.0                    iTBS
# 13                      [-47.3, -68.5, 36.2]      1.0                     NaN
# 14             [-61, -51, 39], [61, -51, 39]      1.0                     NaN
# 15           [30, -88, -35], [-30, -88, -35]      1.0                     NaN
# 16                             [-29, 23, 59]      1.0  Duplicated in Moussavi
# 17                              [0, -70, 44]      1.0                     NaN
# 18                             [-29, 23, 59]      1.0                     NaN
# 19                             [-29, 23, 59]      1.0                     NaN
# 20           [-1.3, 2.8, -1], [1.3, 2.8, -1]      1.0                     NaN
# 21               [-44,40,29], [-69, -8, -10]      0.0              Multifocal
# 22                              [0, -70, 44]      0.0              Duplicated
# 24  [-39.5, -76.3, 47.4], [59.3, -67.3, 3.8]      0.0              Multifocal
# 25               [-35,24,48], [-69, -8, -10]      0.0              Multifocal
# 30                                       NaN      0.0              Multifocal
#
#                                              roi_path  \
# 0   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 1   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 2   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 3   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 4   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 5   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 6   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 7   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 8   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 9   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 10  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 11  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 12  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 13  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 14  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 15  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 16  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 17  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 18  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 19  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 20  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 21  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 22  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 24  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 25  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 30                                                NaN
#
#                                          roi_path_old  \
# 0                                                 NaN
# 1   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 2   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 3                                                 NaN
# 4   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 5   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 6   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 7   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 8   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 9   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 10  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 11  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 12  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 13  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 14  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 15  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 16                                                NaN
# 17  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 18  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 19  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 20  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 21                                                NaN
# 22  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 24  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 25                                                NaN
# 30                                                NaN
#
#                           subject CNM_Damage_Roi_old CNM_Damage_Roi_new
# 0                 Wu_et_al___2024          -0.685000          -0.681262
# 1           Moussavi_et_al___2024          -0.369729          -0.370000
# 2            Cotelli_et_al___2011          -0.510000           0.410000
# 3       Ahmed_et_al___2012__1_Hz_           0.430000           0.430000
# 4                 Li_et_al___2021          -0.615157          -0.620000
# 5                Wei_et_al___2022           0.620000           0.610000
# 6               Koch_et_al___2022           0.545000           0.545000
# 7                Jia_et_al___2021           0.605000           0.610000
# 8    Saitoh_et_al___2022__90_RTM_           0.353568           0.353000
# 9               Kuhn_et_al___2015           0.045051           0.451000
# 10  Saitoh_et_al___2022__120_RTM_           0.333408           0.346747
# 11                Hu_et_al___2022           0.370000           0.370000
# 12                Wu_et_al___2022          -0.685000          -0.690000
# 13              Jung_et_al___2025           0.602000           0.605000
# 14               Liu_et_al___2022           0.210017           0.215000
# 15               Yao_et_al___2022           0.380000           0.385000
# 16        Rutherford_et_al___2015           0.415073           0.415073
# 17              Koch_et_al___2025           0.550000           0.550000
# 18            Padala_et_al___2020           0.330822           0.415073
# 19                Wu_et_al___2015           0.330822           0.420000
# 20            Lozano_et_al___2016           0.590000           0.590000
# 21               Qin_et_al___2023          -0.487645          -0.487645
# 22              Koch_et_al___2018           0.540000           0.540000
# 24              Zhao_et_al___2017           0.200000           0.200000
# 25             Zhang_et_al___2019          -0.487645          -0.487645
# 30                            NaN          -0.487645          -0.487645
#
# [26 rows x 40 columns]

# %% [markdown]
# Set the parameters for dropping rows

# %%
data_df.columns
# Out:
# Index(['Study', 'DOI', 'RCT_Design', 'Age_range', 'CDR', 'Active_N', 'Sham_N',
#        'Mean_Age', 'Active_Age', 'Sham_Age', 'Active_M_F', 'Sham_M_F',
#        'Active_Education__Yrs_', 'Sham_Education__Yrs_',
#        'Active_AD_Treatment_Proportion', 'Diagnosis', 'Diagnostic_Criteria',
#        'Stim_Type', 'Frequency', 'Intensity', 'Navigation',
#        'Total_Pulses_session', 'session', 'Total_pulses',
#        'Overall_Cognition_Test', 'Overall_Cognition_Cohen_s_D', 'Redo_test',
#        'cohens_D_redo', 'Verbal_Memory_Test', 'Memory_Cohen_s_D',
#        'Stimulation_site', 'dlpfc', 'Stim_Coordinate', 'Included',
#        'Exclusion_Reason', 'roi_path', 'roi_path_old', 'subject',
#        'CNM_Damage_Roi_old', 'CNM_Damage_Roi_new', 'cohens_D_redo_residual',
#        'dlpfc_connectivity', 'mask'],
#       dtype='object')

# %%
m1 = data_df['cohens_D_redo_residual'] < -0.1
m2 = data_df['CNM_Damage_Roi_old'] > 0
m3 = m1 & m2
data_df['mask'] = m3

# %%
m3
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 8      True
# 10    False
# 12    False
# 16    False
# 18    False
# 19    False
# dtype: bool

# %%
column = 'mask'  # The column you'd like to evaluate
condition = 'equal'  # Thecondition to check ('equal', 'above', 'below', 'not')
value = True # The value to compare against

# %%
data_df, other_df = cal_palm.drop_rows_based_on_value(column, condition, value)
data_df
# Out:
#                             Study                               DOI  \
# 0                 Wu et al., 2024        10.1136/gpsych-2023-101106
# 1           Moussavi et al., 2024      10.1016/j.neurot.2024.e00331
# 2            Cotelli et al., 2011          10.1136/jnnp.2009.197848
# 3       Ahmed et al., 2012 (1 Hz)         10.1007/s00415-011-6128-4
# 4                 Li et al., 2021         10.1016/j.brs.2021.01.012
# 10  Saitoh et al., 2022 (120%RTM)         10.3389/fnagi.2022.993306
# 12                Wu et al., 2022         10.1016/j.brs.2021.11.007
# 16        Rutherford et al., 2015                10.4137/JEN.S24004
# 18            Padala et al., 2020    10.1016/j.psychres.2017.12.063
# 19                Wu et al., 2015  10.11919/j.issn.1002-0829.215107
#
#    RCT_Design                 Age_range    CDR  Active_N  Sham_N  Mean_Age  \
# 0    Parallel                       ≧50  0.5-2      20.0    22.0      67.0
# 1    Parallel                       >55    1∼2      53.0    51.0      73.0
# 2    Parallel                       NaN    NaN       5.0     5.0      71.0
# 3    Parallel                     60-82    NaN      15.0    15.0      65.0
# 4    Parallel                       NaN    NaN      37.0    38.0      65.0
# 10   Parallel  60–93 (participant data)    1–2      15.0    12.0      76.0
# 12   Parallel                       ≧50     ≦2      24.0    23.0      66.0
# 16  Crossover                     57-87    NaN      10.0    10.0      57.0
# 18   Parallel                       ≧55    NaN       9.0    11.0      74.0
# 19   Parallel                     60–80    NaN      26.0    26.0      71.0
#
#       Active_Age      Sham_Age  ...  Included        Exclusion_Reason  \
# 0    66.8 ± 8.84  65.32 ± 7.31  ...       1.0                    iTBS
# 1     73.3 ± 6.9      75 ± 9.1  ...       1.0                     NaN
# 2     71.2 ± 6.1    74.4 ± 3.8  ...       1.0                     NaN
# 3     65.9 ± 5.9    68.3 ± 4.9  ...       1.0                     NaN
# 4   65.97 ± 8.47  64.58 ± 7.88  ...       1.0                     NaN
# 10          76.2          75.8  ...       1.0                     NaN
# 12  66.46 ± 8.25  66.35 ± 7.99  ...       1.0                    iTBS
# 16            57            57  ...       1.0  Duplicated in Moussavi
# 18    74.3 ± 5.7    79.6 ± 7.7  ...       1.0                     NaN
# 19    71.4 ± 4.9    71.9 ± 4.8  ...       1.0                     NaN
#
#                                              roi_path  \
# 0   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 1   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 2   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 3   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 4   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 10  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 12  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 16  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 18  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 19  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
#
#                                          roi_path_old  \
# 0                                                 NaN
# 1   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 2   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 3                                                 NaN
# 4   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 10  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 12  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 16                                                NaN
# 18  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 19  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
#
#                           subject CNM_Damage_Roi_old CNM_Damage_Roi_new  \
# 0                 Wu_et_al___2024          -0.685000          -0.681262
# 1           Moussavi_et_al___2024          -0.369729          -0.370000
# 2            Cotelli_et_al___2011          -0.510000           0.410000
# 3       Ahmed_et_al___2012__1_Hz_           0.430000           0.430000
# 4                 Li_et_al___2021          -0.615157          -0.620000
# 10  Saitoh_et_al___2022__120_RTM_           0.333408           0.346747
# 12                Wu_et_al___2022          -0.685000          -0.690000
# 16        Rutherford_et_al___2015           0.415073           0.415073
# 18            Padala_et_al___2020           0.330822           0.415073
# 19                Wu_et_al___2015           0.330822           0.420000
#
#    cohens_D_redo_residual dlpfc_connectivity   mask
# 0            8.633806e-02           Negative  False
# 1           -4.015173e-01           Negative  False
# 2           -3.728863e-01           Negative  False
# 3            4.440892e-16           Positive  False
# 4           -2.558348e-01           Negative  False
# 10          -4.597021e-02           Positive  False
# 12          -8.633806e-02           Negative  False
# 16           5.744182e-01           Positive  False
# 18           1.729009e-01           Positive  False
# 19           4.558202e-01           Positive  False
#
# [10 rows x 43 columns]

# %% [markdown]
# Regress out a Covariate

# %%
for col in data_df.columns:
    print(col)
# Out:
# Study
# DOI
# RCT_Design
# Age_range
# CDR
# Active_N
# Sham_N
# Mean_Age
# Active_Age
# Sham_Age
# Active_M_F
# Sham_M_F
# Active_Education__Yrs_
# Sham_Education__Yrs_
# Active_AD_Treatment_Proportion
# Diagnosis
# Diagnostic_Criteria
# Stim_Type
# Frequency
# Intensity
# Navigation
# Total_Pulses_session
# session
# Total_pulses
# Overall_Cognition_Test
# Overall_Cognition_Cohen_s_D
# Redo_test
# cohens_D_redo
# Verbal_Memory_Test
# Memory_Cohen_s_D
# Stimulation_site
# dlpfc
# Stim_Coordinate
# Included
# Exclusion_Reason
# roi_path
# roi_path_old
# subject
# CNM_Damage_Roi_old
# CNM_Damage_Roi_new

# %%
dependent_variable_list = ['cohens_D_redo']
regressors = ['Stimulation_site', 'Frequency']

# %%
for col in regressors:
    if data_df[col].dtype == 'O':  # object/categorical
        data_df[col] = data_df[col].fillna(data_df[col].mode()[0])
    else:  # numeric
        data_df[col] = data_df[col].fillna(data_df[col].mean())
data_df[regressors].isna().sum()
# Out:
# /var/folders/82/946tskyj68b6htgvndtppmz80000gp/T/ipykernel_23531/2443647503.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df[col] = data_df[col].fillna(data_df[col].mode()[0])
# Stimulation_site    0
# Frequency           0
# dtype: int64

# %%
from calvin_utils.statistical_utils.regression_utils import RegressOutCovariates
data_df, adjusted_dep_vars_list = RegressOutCovariates.run(df=data_df, dependent_variable_list=dependent_variable_list, covariates_list=regressors)
print(adjusted_dep_vars_list)
# Out:
#  Formula for cohens_D_redo:
#  cohens_D_redo ~ Stimulation_site + Frequency
# ['cohens_D_redo_residual']
# /Users/cu135/Software_Local/calvin_utils_project/circuit_pyper/calvin_utils/statistical_utils/regression_utils.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{indep_var}_residual"] = residuals

# %% [markdown]
# **Standardize Data**
# - Enter Columns you Don't want to standardize into a list

# %%
data_df.columns
# Out:
# Index(['Study', 'DOI', 'RCT_Design', 'Age_range', 'CDR', 'Active_N', 'Sham_N',
#        'Mean_Age', 'Active_Age', 'Sham_Age', 'Active_M_F', 'Sham_M_F',
#        'Active_Education__Yrs_', 'Sham_Education__Yrs_',
#        'Active_AD_Treatment_Proportion', 'Diagnosis', 'Diagnostic_Criteria',
#        'Stim_Type', 'Frequency', 'Intensity', 'Navigation',
#        'Total_Pulses_session', 'session', 'Total_pulses',
#        'Overall_Cognition_Test', 'Overall_Cognition_Cohen_s_D', 'Redo_test',
#        'cohens_D_redo', 'Verbal_Memory_Test', 'Memory_Cohen_s_D',
#        'Stimulation_site', 'dlpfc', 'Stim_Coordinate', 'Included',
#        'Exclusion_Reason', 'roi_path', 'roi_path_old', 'subject',
#        'CNM_Damage_Roi_old', 'CNM_Damage_Roi_new', 'cohens_D_redo_residual'],
#       dtype='object')

# %%
# Remove anything you don't want to standardize
# cols_not_to_standardize = ['Overall_Cognition_Cohen_s_D']

# %%
# data_df = cal_palm.standardize_columns(cols_not_to_standardize)
data_df
# Out:
#                             Study                                 DOI  \
# 0                 Wu et al., 2024          10.1136/gpsych-2023-101106
# 1           Moussavi et al., 2024        10.1016/j.neurot.2024.e00331
# 2            Cotelli et al., 2011            10.1136/jnnp.2009.197848
# 3       Ahmed et al., 2012 (1 Hz)           10.1007/s00415-011-6128-4
# 4                 Li et al., 2021           10.1016/j.brs.2021.01.012
# 5                Wei et al., 2022      10.1016/j.psychres.2022.114721
# 6               Koch et al., 2022               10.1093/brain/awac285
# 7                Jia et al., 2021           10.3389/fnagi.2021.693611
# 8    Saitoh et al., 2022 (90%RTM)           10.3389/fnagi.2022.993306
# 9               Kuhn et al., 2015  https://doi.org/10.1038/mp.2014.32
# 10  Saitoh et al., 2022 (120%RTM)           10.3389/fnagi.2022.993306
# 11                Hu et al., 2022           10.1016/j.brs.2022.11.009
# 12                Wu et al., 2022           10.1016/j.brs.2021.11.007
# 13              Jung et al., 2025   10.1001/jamanetworkopen.2024.9220
# 14               Liu et al., 2022              10.1093/cercor/bhab371
# 15               Yao et al., 2022           10.1016/j.brs.2022.06.004
# 16        Rutherford et al., 2015                  10.4137/JEN.S24004
# 17              Koch et al., 2025          10.1186/s13195-025-01709-7
# 18            Padala et al., 2020      10.1016/j.psychres.2017.12.063
# 19                Wu et al., 2015    10.11919/j.issn.1002-0829.215107
# 20            Lozano et al., 2016  https://doi.org/10.3233/JAD-160017
#
#    RCT_Design                 Age_range                                   CDR  \
# 0    Parallel                       ≧50                                 0.5-2
# 1    Parallel                       >55                                   1∼2
# 2    Parallel                       NaN                                   NaN
# 3    Parallel                     60-82                                   NaN
# 4    Parallel                       NaN                                   NaN
# 5    Parallel                     55–85                                 0.5–2
# 6    Parallel                     50–85                                 0.5–1
# 7    Parallel                     55–85                                 0.5–2
# 8    Parallel                       NaN                                   NaN
# 9   Crossover                     57-90                                  <0.5
# 10   Parallel  60–93 (participant data)                                   1–2
# 11   Parallel                     60–90                                     2
# 12   Parallel                       ≧50                                    ≦2
# 13   Parallel                     55-90                                 0.5-2
# 14   Parallel                     50–85                                 0.5–1
# 15   Parallel                     60–80  Active:1.07 ± 0.53 Sham: 1.20 ± 0.59
# 16  Crossover                     57-87                                   NaN
# 17   Parallel                     57-90                                 0.5–1
# 18   Parallel                       ≧55                                   NaN
# 19   Parallel                     60–80                                   NaN
# 20   Parallel                       >65                                   0.5
#
#     Active_N  Sham_N  Mean_Age    Active_Age      Sham_Age  ...  dlpfc  \
# 0       20.0    22.0      67.0   66.8 ± 8.84  65.32 ± 7.31  ...    1.0
# 1       53.0    51.0      73.0    73.3 ± 6.9      75 ± 9.1  ...    1.0
# 2        5.0     5.0      71.0    71.2 ± 6.1    74.4 ± 3.8  ...    1.0
# 3       15.0    15.0      65.0    65.9 ± 5.9    68.3 ± 4.9  ...    1.0
# 4       37.0    38.0      65.0  65.97 ± 8.47  64.58 ± 7.88  ...    1.0
# 5       29.0    27.0      70.0     70 ± 8.68  71.67 ± 7.16  ...    0.0
# 6       25.0    25.0      75.0      75 ± 5.6    72.3 ± 7.2  ...    0.0
# 7       35.0    34.0      71.0  71.41 ± 8.85  73.41 ± 7.73  ...    0.0
# 8       13.0     NaN      77.0          77.2           NaN  ...    1.0
# 9        6.0     NaN      69.0    69.5 ± 7.7           NaN  ...    0.0
# 10      15.0    12.0      76.0          76.2          75.8  ...    1.0
# 11      21.0    21.0      76.0  76.86 ± 6.07  75.33 ± 5.73  ...    0.0
# 12      24.0    23.0      66.0  66.46 ± 8.25  66.35 ± 7.99  ...    1.0
# 13      18.0    12.0      69.0    69.8 ± 9.1    69.8 ± 9.1  ...    0.0
# 14      25.0    12.0      67.0  67.28 ± 7.74   72.08 ± 7.3  ...    0.0
# 15      15.0    12.0      63.0  63.87 ± 6.85   67.6 ± 7.88  ...    0.0
# 16      10.0    10.0      57.0            57            57  ...    1.0
# 17      27.0    21.0      74.0      74 ± 5.1   71.2 ± 5.11  ...    0.0
# 18       9.0    11.0      74.0    74.3 ± 5.7    79.6 ± 7.7  ...    1.0
# 19      26.0    26.0      71.0    71.4 ± 4.9    71.9 ± 4.8  ...    1.0
# 20      30.0    15.0      69.0    69.8 ± 8.1    67.8 ± 7.7  ...    0.0
#
#                         Stim_Coordinate Included        Exclusion_Reason  \
# 0                         [-38, 44, 26]      1.0                    iTBS
# 1       [-41.1, 36, 38], [41.1, 36, 38]      1.0                     NaN
# 2                         [-29, 23, 59]      1.0                     NaN
# 3   [-22.7, 38.9, 44], [22.7, 38.9, 44]      1.0                     NaN
# 4                           [-44,40,29]      1.0                     NaN
# 5                        [-47, -68, 36]      1.0                     NaN
# 6                          [0, -70, 44]      1.0                     NaN
# 7                        [-47, -68, 36]      1.0                     NaN
# 8           [-29, 23, 59], [29, 23, 59]      1.0                     NaN
# 9   [-20, -7.1, -8.6], [20, -7.1, -8.6]      1.0             no sham arm
# 10          [-29, 23, 59], [29, 23, 59]      1.0                     NaN
# 11        [63, -53, 27], [-63, -53, 27]      1.0                     NaN
# 12                        [-38, 44, 26]      1.0                    iTBS
# 13                 [-47.3, -68.5, 36.2]      1.0                     NaN
# 14        [-61, -51, 39], [61, -51, 39]      1.0                     NaN
# 15      [30, -88, -35], [-30, -88, -35]      1.0                     NaN
# 16                        [-29, 23, 59]      1.0  Duplicated in Moussavi
# 17                         [0, -70, 44]      1.0                     NaN
# 18                        [-29, 23, 59]      1.0                     NaN
# 19                        [-29, 23, 59]      1.0                     NaN
# 20      [-1.3, 2.8, -1], [1.3, 2.8, -1]      1.0                     NaN
#
#                                              roi_path  \
# 0   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 1   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 2   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 3   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 4   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 5   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 6   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 7   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 8   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 9   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 10  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 11  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 12  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 13  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 14  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 15  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 16  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 17  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 18  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 19  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 20  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
#
#                                          roi_path_old  \
# 0                                                 NaN
# 1   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 2   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 3                                                 NaN
# 4   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 5   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 6   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 7   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 8   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 9   /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 10  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 11  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 12  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 13  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 14  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 15  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 16                                                NaN
# 17  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 18  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 19  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
# 20  /Volumes/HowExp/datasets/05c_Howard_MetaAlzhei...
#
#                           subject CNM_Damage_Roi_old CNM_Damage_Roi_new  \
# 0                 Wu_et_al___2024          -0.685000          -0.681262
# 1           Moussavi_et_al___2024          -0.369729          -0.370000
# 2            Cotelli_et_al___2011          -0.510000           0.410000
# 3       Ahmed_et_al___2012__1_Hz_           0.430000           0.430000
# 4                 Li_et_al___2021          -0.615157          -0.620000
# 5                Wei_et_al___2022           0.620000           0.610000
# 6               Koch_et_al___2022           0.545000           0.545000
# 7                Jia_et_al___2021           0.605000           0.610000
# 8    Saitoh_et_al___2022__90_RTM_           0.353568           0.353000
# 9               Kuhn_et_al___2015           0.045051           0.451000
# 10  Saitoh_et_al___2022__120_RTM_           0.333408           0.346747
# 11                Hu_et_al___2022           0.370000           0.370000
# 12                Wu_et_al___2022          -0.685000          -0.690000
# 13              Jung_et_al___2025           0.602000           0.605000
# 14               Liu_et_al___2022           0.210017           0.215000
# 15               Yao_et_al___2022           0.380000           0.385000
# 16        Rutherford_et_al___2015           0.415073           0.415073
# 17              Koch_et_al___2025           0.550000           0.550000
# 18            Padala_et_al___2020           0.330822           0.415073
# 19                Wu_et_al___2015           0.330822           0.420000
# 20            Lozano_et_al___2016           0.590000           0.590000
#
#    cohens_D_redo_residual
# 0            8.633806e-02
# 1           -4.659470e-01
# 2           -4.051011e-01
# 3            6.661338e-16
# 4           -2.880496e-01
# 5            1.346145e-15
# 6           -2.616230e-01
# 7           -2.255039e-01
# 8           -6.250105e-02
# 9            9.992007e-16
# 10           1.845946e-02
# 11           3.885781e-16
# 12          -8.633806e-02
# 13           2.255039e-01
# 14           5.551115e-17
# 15           8.326673e-16
# 16           5.099886e-01
# 17           2.616230e-01
# 18           2.695454e-01
# 19           4.236053e-01
# 20           1.110223e-15
#
# [21 rows x 41 columns]

# %% [markdown]
# Misc Filtering

# %%
# data_df = data_df[data_df['Pre_Post_Memory_Effect_Size__Cohen_s_D_'].abs() <= 10]
q1 = data_df['cohens_D_redo_residual'].quantile(0.25)
q3 = data_df['cohens_D_redo_residual'].quantile(0.75)
iqr = q3 - q1
data_df['outlier'] = data_df['cohens_D_redo_residual'] > (q3 + 1.5*iqr)
data_df['outlier'] = data_df['cohens_D_redo_residual'] < (q1 - 1.5*iqr)
data_df['outlier']
# Out:
# /var/folders/82/946tskyj68b6htgvndtppmz80000gp/T/ipykernel_23531/1576538837.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df['outlier'] = data_df['cohens_D_redo_residual'] > (q3 + 1.5*iqr)
# /var/folders/82/946tskyj68b6htgvndtppmz80000gp/T/ipykernel_23531/1576538837.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df['outlier'] = data_df['cohens_D_redo_residual'] < (q1 - 1.5*iqr)
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# Name: outlier, dtype: bool

# %% [markdown]
# # 02 - Perform Basic Correlation

# %%
data_df.columns

# %%
x_col = 'CNM_Damage_Roi_old'
y_col = 'cohens_D_redo_residual'

# %%
from calvin_utils.statistical_utils.scatterplot import simple_scatter
simple_scatter(data_df, x_col, y_col, '', 
               x_label="Spatial Correlation",
               y_label="Cognitive Outcome (Adj. Cohen's D)",
               out_dir=out_dir, flip_axes=False)
# Out:
# <Axes: xlabel='Spatial Correlation', ylabel="Cognitive Outcome (Adj. Cohen's D)">

# %%
import numpy as np 
data_df['dlpfc_connectivity'] = np.where(data_df['CNM_Damage_Roi_old']>0, 'Positive', 'Negative')
# Out:
# /var/folders/82/946tskyj68b6htgvndtppmz80000gp/T/ipykernel_23531/2541992678.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df['dlpfc_connectivity'] = np.where(data_df['CNM_Damage_Roi_old']>0, 'Positive', 'Negative')

# %%
from calvin_utils.plotting_utils.simple_box_plot import SimpleBoxPlotPair

plotter = SimpleBoxPlotPair(data_df,
                            group_col="dlpfc_connectivity",
                            value_col='cohens_D_redo_residual',
                            dataset_name='dlPFC',
                            out_dir=out_dir,
                            xlabel='Spatial Correlation',
                            ylabel="Cognitive Outcome (Adj. Cohen's D)",
                            figsize=(5,6)).run()
# Out:
# /Users/cu135/Software_Local/calvin_utils_project/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/cu135/Software_Local/calvin_utils_project/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/cu135/Software_Local/calvin_utils_project/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# Check p-values with Permutation

# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
spearman = []
pearson = []

x = data_df['cohens_D_redo_residual']
y = data_df['CNM_Damage_Roi_old']

rho_real, _ = spearmanr(x,y)
r_real, _  = pearsonr(x,y)

for i in range(0,10000):
    x = data_df['cohens_D_redo_residual']
    y = np.random.choice(data_df['CNM_Damage_Roi_old'], size=len(data_df['CNM_Damage_Roi_old']), replace=False)
    rho, _ = spearmanr(x,y)
    r, _ = pearsonr(x,y)
    spearman.append(rho)
    pearson.append(r)

rho_p = np.mean(rho_real < np.array(spearman))
r_p = np.mean(r_real < np.array(pearson))

print(rho_p, r_p)

# %%
r_real

# %%
data_df.columns

# %%
import itertools
from scipy.stats import pearsonr, spearmanr
from calvin_utils.statistical_utils.regression_utils import RegressOutCovariates

scores = ['score', 0, 0]
dependent_variable_list = ['cohens_D_redo']
covariate_options = ['DOI', 'RCT_Design', 'Age_range', 'CDR', 'Active_N', 'Sham_N',
       'Mean_Age', 'Active_Age', 'Sham_Age', 'Active_M_F', 'Sham_M_F',
       'Active_Education__Yrs_', 'Sham_Education__Yrs_',
       'Active_AD_Treatment_Proportion', 'Diagnosis', 'Diagnostic_Criteria',
       'Stim_Type', 'Frequency', 'Intensity', 'Navigation',
       'Total_Pulses_session', 'session', 'Total_pulses',
       'Overall_Cognition_Test', 'Redo_test', 'Verbal_Memory_Test', 'Memory_Cohen_s_D',
       'Stimulation_site', 'Stim_Coordinate', 'Included', 'Exclusion_Reason', 'subject']
for combination in itertools.combinations(covariate_options, 3):
    covariates = list(combination)
    data_df, adjusted_dep_vars_list = RegressOutCovariates.run(df=data_df, dependent_variable_list=dependent_variable_list, covariates_list=covariates)
    res_col = adjusted_dep_vars_list[0]
    r, p = spearmanr(data_df.loc[:, res_col], data_df.loc[:, 'CNM_Damage_Roi_old'], alternative='two-sided')
    if r > scores[1]:
        scores[0] = combination
        scores[1] = r
        scores[2] = p

# %%
print(scores)

# %% [markdown]
# # Correlate Variable with All Other Variables

# %%
x_col = 'flipped_lesions_all_datasets_weighted_avg_r_map_cosine'

# %%
from calvin_utils.statistical_utils.correlation_barplot import CorrelationBarPlot
plotter = CorrelationBarPlot(data_df, x_col=x_col, method="spearman")
corr_series = plotter.run(save_path=None)

# %% [markdown]
# Focus on correlations above a threhsold

# %%
strong_corrs = plotter.plot_threshold(0.3)      # |r| ≥ 0.4 plot
