# %% [markdown]
# # SimpleAUROC
#
# Quick usage example (wide format).

# %%
import pandas as pd
from calvin_utils.plotting_utils.simple_auroc import SimpleAUROC

# Load your CSV (wide format)
csv_path = '/path/to/your.csv'
df = pd.read_csv(csv_path)

plotter = SimpleAUROC(
    df,
    outcome_col='y_true',
    prob_cols=['model_a_prob', 'model_b_prob'],
    dataset_name='AUROC Example',
    out_dir=None,
)
plotter.run()
