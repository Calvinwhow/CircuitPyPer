# %% [markdown]
# # SimpleLinePlot
#
# Quick usage example (wide format).

# %%
import pandas as pd
from calvin_utils.plotting_utils.simple_line_plot import SimpleLinePlotWrapper

# Load your CSV (wide format)
csv_path = '/path/to/your.csv'
df = pd.read_csv(csv_path)

plotter = SimpleLinePlotWrapper(df)
plotter.plot(
    x_col='x',  # set to None if no explicit x column
    series_cols=None,  # or list the series columns explicitly
    dataset_name='Line Plot Example',
)
