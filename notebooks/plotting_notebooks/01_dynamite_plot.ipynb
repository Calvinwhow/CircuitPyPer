# %% [markdown]
# # SimpleDynamitePlot
#
# Quick usage example (wide format).

# %%
import pandas as pd
from calvin_utils.plotting_utils.simple_dynamite_plot import SimpleDynamitePlotWrapper

# Load your CSV (wide format)
csv_path = '/path/to/your.csv'
df = pd.read_csv(csv_path)

plotter = SimpleDynamitePlotWrapper(df)
plotter.plot(
    columns=['group_a', 'group_b'],
    group_labels=['Group A', 'Group B'],
    dataset_name='Dynamite Plot Example',
    xlabel='Group',
    ylabel='Value'
)

# %%
import pandas as pd
from calvin_utils.plotting_utils.simple_dynamite_plot import SimpleDynamitePlotWrapper
# Load your CSV (wide format)
csv_path = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/vta_centroids_comparison/overall/bilateral/centroids_paired.csv'
df = pd.read_csv(csv_path)

plotter = SimpleDynamitePlotWrapper(df)

plotter.plot(
    columns=[('x_a', 'x_b'), ('y_a', 'y_b'), ('z_a', 'z_b'), ('l2_a', 'l2_b')],
    group_labels=['X', 'Y', 'Z', 'L2'],
    pair_names=['A', 'B'],
    dataset_name='Pairwise Dynamite Plot',
    xlabel='Metric',
    ylabel='Value'
)
