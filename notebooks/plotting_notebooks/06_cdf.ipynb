# %% [markdown]
# # SimpleCdfPlot
#
# Quick usage example (wide format).

# %%
import pandas as pd
from calvin_utils.plotting_utils.simple_cdf_plot import SimpleCdfPlot

# Load your CSV (wide format)
csv_path = '/path/to/your.csv'
df = pd.read_csv(csv_path)

plotter = SimpleCdfPlot(
    df,
    value_cols=['A', 'B'],
    dataset_name='CDF Example',
    out_dir=None,
)
plotter.run()
