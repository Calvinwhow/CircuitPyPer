# %%
from calvin_utils.neuroimaging_utils.nifti_utils.cerebellum_plot import SUITCerebellumPlotter

plotter = SUITCerebellumPlotter('/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/correlation_in_maps/CNRSTotScore.nii.gz')
plotter.run(
    space="MNI",
    out_file="/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/correlation_in_maps/CNRSTotScore-cerebe-parcels-rdbu.svg",
    cmap="RdBu",
    colorbar=True,
    cscale = [-1, 1],
    threshold =  [-0.01, 0.01]
)
# Out:
# <Axes: >

# %% [markdown]
# Plot without background cerebellum

# %%
from calvin_utils.neuroimaging_utils.nifti_utils.cerebellum_plot import SUITCerebellumPlotter
plotter = SUITCerebellumPlotter("/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/symptom_on_lhs/ccas/standardized-perm1000/regression_0/contrast_tval_FWE_0.nii.gz")

plotter.plot_without_background(
    space="MNI",
    out_file="/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/raynor_network_mapping/figures/schmahmann_cerebellar_ataxia/symptom_maps/ccas-cerebe-fwe.svg",
    cmap="/Users/cu135/Software_Local/calvin_utils_project/circuit_pyper/resources/colour_luts/6bluegrn.clut",
    colorbar=True,
    cscale=[0.05, 3],
    threshold=0.5,
)
# Out:
# <Axes: >
