# %%
from calvin_utils.neuroimaging_utils.nifti_utils.cerebellum_plot import SUITCerebellumPlotter

plotter = SUITCerebellumPlotter('/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/symptom_on_lhs/proper_regressions_clusters/cluster_1-on-image_path/parcellated_files/contrast_tval_FWE_0_diedrichsen-wholebrain.nii.gz')
plotter.run(
    space="MNI",
    out_file="/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/raynor_network_mapping/figures/schmahmann_cerebellar_ataxia/symptom_clusters/bg.svg",
    cmap="#9a8ed1",
    colorbar=True,
    cscale = [100, 500],
    threshold =  [100, 120]
)
# Out:
# Hexcode cmap detected for #9a8ed1. Generating linear cmap from white to hexcode target.
# <Axes: >

# %% [markdown]
# Plot without background cerebellum

# %%
from calvin_utils.neuroimaging_utils.nifti_utils.cerebellum_plot import SUITCerebellumPlotter
plotter = SUITCerebellumPlotter('/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/symptom_on_lhs/proper_regressions_clusters/cluster_1-on-image_path/parcellated_files/contrast_tval_FWE_0_diedrichsen-wholebrain.nii.gz')

plotter.plot_without_background(
    space="MNI",
    out_file="/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/raynor_network_mapping/figures/schmahmann_cerebellar_ataxia/symptom_clusters/emotional-nobg.svg",
    cmap="#9a8ed1",
    colorbar=True,
    cscale=[0.0001, 5],
    threshold=[-0.01, 0.01]
)
# Out:
# Hexcode cmap detected for #9a8ed1. Generating linear cmap from white to hexcode target.
# <Axes: >
