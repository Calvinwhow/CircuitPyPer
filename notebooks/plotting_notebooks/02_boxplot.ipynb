# %% [markdown]
# # 02 Boxplot
#
# Quick usage example (wide format).

# %%
import pandas as pd
csv_path = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/atrophy_seeds_2023/Figures/supplements_validation_corr-to-adas/comparisons.csv'
df = pd.read_csv(csv_path)

# %% [markdown]
# Unpaired comparison

# %%
from calvin_utils.plotting_utils.simple_box_plot import SimpleBoxPlotWrapper
plotter = SimpleBoxPlotWrapper(df)
plotter.plot(
    columns=['CSF', 'GM', 'WM', 'CTH'],
    group_labels=['CSF', 'GM', 'WM', 'CTh'],
    dataset_name='Validation',
    xlabel='',
    ylabel='Correlation to Cognitive Baseline',
    figsize=(11,5),
    out_dir='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/atrophy_seeds_2023/Figures/supplements_validation_corr-to-adas'
)
# Out:
# /Users/cu135/Software_Local/calvin_utils_project/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/cu135/Software_Local/calvin_utils_project/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/cu135/Software_Local/calvin_utils_project/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# Pairwise Comparison

# %%
df
# Out:
#     CSF    GM    WM   CTH  Standard Methods
# 0  0.28  0.45  0.21  0.41               NaN
# 1  0.24  0.05  0.12  0.00               NaN
# 2  0.22  0.16  0.05  0.28               NaN
# 3  0.42  0.14  0.01  0.17               NaN
# 4  0.26  0.09  0.02  0.28               NaN
# 5  0.39  0.00  0.00  0.22               NaN
# 6  0.37  0.32  0.04  0.00               NaN

# %%
from calvin_utils.plotting_utils.simple_box_plot import SimpleBoxPlotWrapper

plotter = SimpleBoxPlotWrapper(df)
plotter.plot(
    columns=[('CSF', 'GM'), ('CSF','WM'), ('CSF','CTH')],
    group_labels=['CSF vs. GM', 'CSF vs. WM', 'CSF vs. CTh'],
    pair_names=['CSF', 'Standard Method'],
    dataset_name='Atrophy Measurements',
    xlabel='Atrophy Method',
    ylabel='Correlation to Cognitive Baseline ADAS-Cog 11 (Pearson R)',
    figsize=(11,5),
    out_dir='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/vta_centroids_comparison/overall/bilateral/norm'
)
# Out:
# /Users/cu135/Software_Local/calvin_utils_project/.venv/lib/python3.10/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)
# /Users/cu135/Software_Local/calvin_utils_project/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/cu135/Software_Local/calvin_utils_project/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
