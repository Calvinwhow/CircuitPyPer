# %% [markdown]
# # PairSuperiorityPlot
#
# Quick usage example (wide format).

# %%
# Load your CSV (paired columns)
import pandas as pd

csv_path = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/ccm_memory/results/supplements/vlsm/ad_tms/master_list/master_list_pearson_bootstrap_values.csv'
df = pd.read_csv(csv_path)
df['vlsm_abs_pearson'] = df['vlsm_abs_pearson']/5

df['old_cnm_abs_pearson'] = df['old_cnm_abs_pearson']/3
df
# Out:
#       vlsm_abs_pearson  old_cnm_abs_pearson  delta_vlsm_minus_old
# 0             0.043071             0.071947             -0.000486
# 1             0.023789             0.160660             -0.363034
# 2             0.003976             0.032215             -0.076766
# 3             0.046134             0.075704              0.003556
# 4             0.048411             0.106842             -0.078469
# ...                ...                  ...                   ...
# 9995          0.056594             0.091202              0.009365
# 9996          0.022205             0.150834             -0.341478
# 9997          0.066437             0.025021              0.257120
# 9998          0.101745             0.175637             -0.018189
# 9999          0.012078             0.123883             -0.311258
#
# [10000 rows x 3 columns]

# %%
from calvin_utils.plotting_utils.pair_superiority_plot import PairSuperiorityPlot



plotter = PairSuperiorityPlot(
    stat_array_1=df['old_cnm_abs_pearson'],
    stat_array_2=df['vlsm_abs_pearson'],
    model1_name='Convergent. \n Network',
    model2_name='Convergent. \n VLSM',
    out_dir='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/ccm_memory/results/supplements/ad_tms',
    method='bootstrap',
)
plotter.draw()
# Out:
# Confidence Interval Method: Empiric Percentile
# /Users/cu135/Software_Local/calvin_utils_project/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
