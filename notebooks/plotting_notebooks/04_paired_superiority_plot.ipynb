# %% [markdown]
# # PairSuperiorityPlot
#
# Quick usage example (wide format).

# %%
import pandas as pd
from calvin_utils.plotting_utils.pair_superiority_plot import PairSuperiorityPlot

# Load your CSV (paired columns)
csv_path = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/spreadsheets/master_list.csv'
df = pd.read_csv(csv_path)

plotter = PairSuperiorityPlot(
    stat_array_1=df['avg_memnet_in_clinicianvta'],
    stat_array_2=df['avg_memnet_in_optimizervta'],
    model1_name='Clinician',
    model2_name='Optimized',
    stat='Overlap',
    out_dir='/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/overlap_with_target/fornix',
    method='bootstrap',
)
plotter.draw()
# Out:
# Confidence Interval Method: Empiric Percentile
# /Users/cu135/Software_Local/calvin_utils_project/.venv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
