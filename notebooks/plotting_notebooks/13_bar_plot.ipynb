# %%
import pandas as pd
from calvin_utils.plotting_utils.simple_bar_plot import SimpleBarPlotWrapper

csv_path = "/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/symptoms_on_rhs/batch_cv_loocv/batch_05b_summary.csv"
df = pd.read_csv(csv_path)

bars = "r_squared"
labels = "predictor"

ax = SimpleBarPlotWrapper(df).plot(
    bars,
    labels,
    dataset_name="LOOCV R-squared by Predictor",
    flip=True,              # True = horizontal bars
    sort_by_value=True,
    figsize=(12, 24),
    xlabel="R-squared",
    ylabel="Predictor",
    palette="viridis",
    out_dir='/Volumes/OneTouch/01p_Schmahmann_SCA_Atrophy/results/optimzation/symptoms_on_rhs/batch_cv_loocv'
)
