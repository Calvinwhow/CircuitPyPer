# %% [markdown]
# Usually can be run after circuit_pyper/notebooks/neuroimaging_notebooks/brain_mapping/09a_damage_score_fast.ipynb

# %%
from calvin_utils.plotting_utils.simple_damage_plotter import SimpleDamagePlotter

plotter = SimpleDamagePlotter(
    csv_path="/Volumes/HowExp/datasets/03h_ADVANCE_Alzheimer_DBS/metadata/Fnm_ADvanceI_ADASComponents_Long_Month24.csv",
    x_col="tconn",
    y_col="ADASInstructionsScore",
    color_col="",  # optional
    dataset_name="damage_scatter",
    output_dir="/Users/cu135/hires_backdrops/test/REPRODUCTION_AD_FX_Q4",
)
plotter.plot_four_panel()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 11
#       1 from calvin_utils.plotting_utils.simple_damage_plotter import SimpleDamagePlotter
#       3 plotter = SimpleDamagePlotter(
#       4     csv_path="/Volumes/HowExp/datasets/03h_ADVANCE_Alzheimer_DBS/metadata/Fnm_ADvanceI_ADASComponents_Long_Month24.csv",
#       5     x_col="tconn",
#    (...)
#       9     output_dir="/Users/cu135/hires_backdrops/test/REPRODUCTION_AD_FX_Q4",
#      10 )
# ---> 11 plotter.plot_four_panel()
#
# File ~/Software_Local/calvin_utils_project/circuit_pyper/calvin_utils/plotting_utils/simple_damage_plotter.py:107, in SimpleDamagePlotter.plot_four_panel(self)
#     104 x_label = self.x_label or self.x_col
#     105 y_label = self.y_label or self.y_col
# --> 107 x = df[self.x_col].astype(float)
#     108 y = df[self.y_col].astype(float)
# ...
