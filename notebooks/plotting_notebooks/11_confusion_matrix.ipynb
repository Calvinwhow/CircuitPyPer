# %% [markdown]
# # SimpleConfusionMatrix
#
# Quick usage example (wide format).

# %%
import pandas as pd
from calvin_utils.plotting_utils.simple_confusion_matrix import SimpleConfusionMatrix

# Load your CSV (wide format)
csv_path = '/path/to/your.csv'
df = pd.read_csv(csv_path)

plotter = SimpleConfusionMatrix(
    df,
    true_col='y_true',
    pred_col='y_pred',
    labels=None,
    normalize=None,  # options: None, 'true', 'pred', 'all'
    dataset_name='Confusion Matrix Example',
    out_dir=None,
)
plotter.run()
