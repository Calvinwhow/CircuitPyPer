# %% [markdown]
# # SimpleRadarPlot
#
# Quick usage example.

# %%
import pandas as pd
from calvin_utils.plotting_utils.simple_radar_plot import SimpleRadarPlot

# Load your CSV (variable column + metrics)
csv_path = '/path/to/your.csv'
df = pd.read_csv(csv_path)

plotter = SimpleRadarPlot(
    dataframe=df,
    variable_col='Variable',
    metric_cols=['Accuracy', 'F1', 'AUC'],
    dataset_name='Radar Plot Example',
    out_dir=None,
)
plotter.run()
