# %%
path_1 = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/spreadsheets/master_list.csv'
path_2 = '/Volumes/HowExp/datasets/03h_ADVANCE_Alzheimer_DBS/metadata/Fnm_ADvanceI_ADASComponents_Baseline_Long.csv'

# %%
import pandas as pd
df1 = pd.read_csv(path_1)
df2 = pd.read_csv(path_2)
df2

# %%
df1['subject'].astype(str)
df2['subject'].astype(str)

# %%
merged_df = pd.merge(df1, df2, on='subject', how='outer')
merged_df

# %%
merged_df.to_csv('/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/spreadsheets/master_list.csv', index=False)
