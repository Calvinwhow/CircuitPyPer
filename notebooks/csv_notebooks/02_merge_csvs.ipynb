# %%
path_1 = '/Users/cu135/Downloads/master_list_v2.csv'
path_2 = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/memory_dbs/results/similarity_to_optimal/over65/bilateral/overlap-stimpyper_optimized_bilateral_vtas-stimpyper_clinician_bilateral_vtas.csv'

# %%
import pandas as pd
df1 = pd.read_csv(path_1)
df2 = pd.read_csv(path_2)
df2
# Out:
#     subject  Month_12_Delta_ADASMem  \
# 0       102                    -6.0
# 1       103                    -4.0
# 2       106                    -6.0
# 3       109                    -6.0
# 4       110                     3.0
# 5       113                   -14.0
# 6       114                    -7.0
# 7       116                    -5.0
# 8       119                    -1.0
# 9       120                     NaN
# 10      121                    -4.0
# 11      125                     1.0
# 12      126                    -7.0
# 13      127                    -1.0
# 14      128                    -6.0
# 15      129                    -2.0
# 16      130                    -7.0
# 17      131                     0.0
# 18      133                    -5.0
# 19      134                     0.0
# 20      138                    -2.0
# 21      140                     1.0
# 22      141                   -20.0
# 23      142                     3.0
# 24      143                    -3.0
# ...

# %%
df1['subject'].astype(str)
df2['subject'].astype(str)
# Out:
# 0     102
# 1     103
# 2     106
# 3     109
# 4     110
# 5     113
# 6     114
# 7     116
# 8     119
# 9     120
# 10    121
# 11    125
# 12    126
# 13    127
# 14    128
# 15    129
# 16    130
# 17    131
# 18    133
# 19    134
# 20    138
# 21    140
# 22    141
# 23    142
# 24    143
# 25    144
# 26    145
# 27    146
# 28    149
# 29    150
# Name: subject, dtype: object

# %%
merged_df = pd.merge(df1, df2, on='subject', how='outer')
merged_df
# Out:
#      cohort_key stimulation_modality subject_id  subject  delta_adasmem  \
# 0    fornix_dbs                  DBS    sub-101    101.0            NaN
# 1    fornix_dbs                  DBS    sub-102    102.0            NaN
# 2    fornix_dbs                  DBS    sub-103    103.0            NaN
# 3    fornix_dbs                  DBS    sub-105    105.0            NaN
# 4    fornix_dbs                  DBS    sub-106    106.0            NaN
# ..          ...                  ...        ...      ...            ...
# 113         bnm                  DBS       Pat8      NaN            NaN
# 114         bnm                  DBS       Pat9      NaN            NaN
# 115         bnm                  DBS       Pat4      NaN            NaN
# 116         bnm                  DBS      Pat10      NaN            NaN
# 117         bnm                  DBS      Pat11      NaN            NaN
#
#      percent_improvement_adas   age  baseline_adas  followup_adas  \
# ...

# %%
merged_df.to_csv('/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/atrophy_and_stim/data/master_list_v2.csv', index=False)
